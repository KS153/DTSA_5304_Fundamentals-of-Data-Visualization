# %%
# Google Colab環境ではGoogle Driveをマウントしてアクセスできるようにします。
import sys

if 'google.colab' in sys.modules:
    # Google Drive をマウントします
    from google.colab import drive
    mount_dir = "/content/drive"
    drive.mount(mount_dir)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 設定

# %%
pip install spire.pdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 19.9 MB/s eta 0:00:00
# ...

# %%
pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.0 MB/s eta 0:00:00
# ...

# %%
pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 kB 4.0 MB/s eta 0:00:00
# ...

# %%
pip install pycryptodome
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 33.7 MB/s eta 0:00:00
# ...

# %%
# !pip install openai==1.40.6 httpx==0.27.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: openai
#     Found existing installation: openai 1.61.1
#     Uninstalling openai-1.61.1:
#       Successfully uninstalled openai-1.61.1
# ...

# %%
# !pip install langchain-core==0.3.0 langchain-openai==0.2.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.1/405.1 kB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.8/311.8 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.6
#     Uninstalling langsmith-0.3.6:
#       Successfully uninstalled langsmith-0.3.6
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.33
#     Uninstalling langchain-core-0.3.33:
#       Successfully uninstalled langchain-core-0.3.33
# ...

# %%
# !pip install langchain-community==0.3.0 GitPython==3.1.43
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 27.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.0/413.0 kB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: GitPython
#     Found existing installation: GitPython 3.1.44
#     Uninstalling GitPython-3.1.44:
#       Successfully uninstalled GitPython-3.1.44
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.0
#     Uninstalling langchain-core-0.3.0:
#       Successfully uninstalled langchain-core-0.3.0
# ...

# %%
# !pip install langchain-text-splitters==0.3.0
# Out:
# ...
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.5
#     Uninstalling langchain-text-splitters-0.3.5:
#       Successfully uninstalled langchain-text-splitters-0.3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.17 requires langchain-text-splitters<0.4.0,>=0.3.3, but you have langchain-text-splitters 0.3.0 which is incompatible.
# ...

# %%
# !pip install langchain-chroma==0.1.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 27.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 34.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 7.5 MB/s eta 0:00:00
# ...

# %%
pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 23.9 MB/s eta 0:00:00
# ...

# %%
pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 31.5 MB/s eta 0:00:00
# ...

# %%
pip install pytesseract pillow openai

# %%
pip install pytesseract pillow openai pdf2image

# %%
# !apt install libimage-exiftool-perl
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libarchive-zip-perl libmime-charset-perl libsombok3 libunicode-linebreak-perl
# Suggested packages:
#   libposix-strptime-perl libencode-hanextra-perl libpod2-base-perl
# The following NEW packages will be installed:
#   libarchive-zip-perl libimage-exiftool-perl libmime-charset-perl libsombok3
#   libunicode-linebreak-perl
# 0 upgraded, 5 newly installed, 0 to remove and 20 not upgraded.
# Need to get 3,964 kB of archives.
# After this operation, 23.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libarchive-zip-perl all 1.68-1 [90.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libimage-exiftool-perl all 12.40+dfsg-1 [3,717 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmime-charset-perl all 1.012.2-1 [30.9 kB]
# ...

# %% [markdown]
# # OCR１～３回目

# %%
##### OCR １回目

from spire.pdf import PdfDocument
from spire.pdf import PdfTextExtractOptions
from spire.pdf import PdfTextExtractor

import pdfplumber

"""
# PDFファイルからテキストを抽出する関数
def extract_text_from_pdf(pdf_path):
    # PdfDocumentオブジェクトを作成し、PDFファイルをロード
    pdf = PdfDocument()
    pdf.LoadFromFile(pdf_path)

    # 抽出されたテキストを保存する文字列オブジェクトを作成
    extracted_text = ""

    # PdfTextExtractOptionsオブジェクトを作成
    extract_options = PdfTextExtractOptions()

    # ドキュメント内のページをループ
    for i in range(pdf.Pages.Count):
        # ページを取得
        page = pdf.Pages.get_Item(i)
        # PdfTextExtractorオブジェクトを作成
        text_extractor = PdfTextExtractor(page)
        # ページからテキストを抽出
        text = text_extractor.ExtractText(extract_options)
        # 抽出されたテキストを文字列オブジェクトに追加
        extracted_text += text

    pdf.Close()
    return extracted_text
"""


def extract_content_from_pdf(file_path):
    """
    PDFファイルからテキストと表を抽出します。
    """
    all_content = []
    with pdfplumber.open(file_path) as pdf:
        for page_number, page in enumerate(pdf.pages, start=1):
            text = page.extract_text()
            if text:
                all_content.append(f"--- Page {page_number} ---\n{text}")

            # テーブルの抽出
            tables = page.find_tables()
            if tables:
                table_content = tables[0].extract()
                all_content.append("\n".join(["\t".join(cell if cell is not None else "" for cell in row) for row in table_content]))

            tables = page.extract_tables()
            for table_index, table in enumerate(tables):
                all_content.append(f"--- Table {table_index + 1} on Page {page_number} ---")
                for row in table:
                  if row is not None:
                    # None を無視して行をタブ区切りで結合
                    all_content.append("\t".join(cell if cell is not None else "" for cell in row))
                    #print(row)

    return "\n\n".join(all_content)



# PDFファイルが含まれるフォルダ
pdf_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents"
# 抽出されたテキストファイルを保存するフォルダ
output_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text"

# 出力フォルダが存在しない場合は作成
os.makedirs(output_folder, exist_ok=True)

# PDFフォルダ内のすべてのファイルをループ
for filename in os.listdir(pdf_folder):
    if filename.endswith(".pdf"):
        pdf_path = os.path.join(pdf_folder, filename)
        extracted_text = extract_content_from_pdf(pdf_path)

        # 抽出されたテキストをPDFファイルと同じ名前のテキストファイルに保存
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.txt")
        with open(output_path, "w", encoding="utf-8") as file:
            file.write(extracted_text)

print("すべてのPDFファイルからのテキスト抽出が完了しました。")
# Out:
# WARNING:pdfminer.pdftypes:Data-loss while decompressing corrupted data
# WARNING:pdfminer.pdftypes:Data-loss while decompressing corrupted data
# すべてのPDFファイルからのテキスト抽出が完了しました。

# %%
##### pdfplumber（OCR ２回目）

import pdfplumber
from operator import itemgetter
import os

def extract_contents(page):
    """PDFページから重複しないテキストおよび表データを抽出する。"""
    contents = []
    tables = page.find_tables(table_settings={"horizontal_strategy": "text"})

    # テーブルに含まれないすべてのテキストデータを抽出
    non_table_content = page
    for table in tables:
        # バウンディングボックスの範囲を調整
        adjusted_bbox = (
            max(0, table.bbox[0]),
            max(0, table.bbox[1]),
            min(page.width, table.bbox[2]),
            min(page.height, table.bbox[3])
        )
        # 幅と高さが負にならないようにチェック
        if adjusted_bbox[2] > adjusted_bbox[0] and adjusted_bbox[3] > adjusted_bbox[1]:
            non_table_content = non_table_content.outside_bbox(adjusted_bbox)

    for line in non_table_content.extract_text_lines():
        contents.append({'top': line['top'], 'text': line['text']})

    # すべての表データを抽出
    for table in tables:
        contents.append({'top': table.bbox[1], 'table': table})

    # 行を上部位置でソート
    contents = sorted(contents, key=itemgetter('top'))

    return contents

def sanitize_cell(cell):
    """セルの内容を整理する。"""
    if cell is None:
        return ""
    else:
        # すべての種類の空白を削除し、文字列であることを保証
        return ' '.join(str(cell).split())

def save_to_markdown(directory, file_prefix, original_filename, page_number, contents):
    """抽出した内容をMarkdownファイルに保存する。"""
    base_filename = os.path.splitext(original_filename)[0]
    filename = f"{file_prefix}_{base_filename}_page_{page_number}.md"
    filepath = os.path.join(directory, filename)
    if not os.path.exists(directory):
        os.makedirs(directory)

    with open(filepath, 'w', encoding='utf-8') as file:
        file.write(f'# Page {page_number}\n\n')

        for content in contents:
            if 'text' in content:
                # テキスト内容を段落として書き込む
                file.write(f"{content['text']}\n\n")
            elif 'table' in content:
                table = content['table']
                unsanitized_table = table.extract()  # 表オブジェクトからデータを抽出
                sanitized_table = [[sanitize_cell(cell) for cell in row] for row in unsanitized_table]
                # ヘッダーセパレーターを作成
                header_separator = '|:--' * len(sanitized_table[0]) + ':|\n'
                # テーブルデータをMarkdown形式に変換
                for i, row in enumerate(sanitized_table):
                    md_row = '| ' + ' | '.join(row) + ' |\n'
                    file.write(md_row)
                    # 最初の行（ヘッダー行）の後にヘッダーセパレーターを追加
                    if i == 0:
                        file.write(header_separator)
                # テーブルの後にセパレーターを追加（任意）
                file.write('\n---\n\n')

        print(f"{page_number} has been written to {filename}")

def process_pdf(pdf_path, output_dir, file_prefix):
    """PDFの各ページを処理して別々のMarkdownファイルに保存する。"""
    original_filename = os.path.basename(pdf_path)
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages):
            lines = extract_contents(page)
            save_to_markdown(output_dir, file_prefix, original_filename, i+1, lines)

# PDFファイルが含まれるフォルダ
pdf_folder = "/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents"
# 抽出されたテキストファイルを保存するフォルダ
output_folder = "/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text"
# ファイルプレフィックスを定義
file_prefix = 'iryohi_md'

# 出力フォルダが存在しない場合は作成
os.makedirs(output_folder, exist_ok=True)

# PDFフォルダ内のすべてのファイルをループ
for filename in os.listdir(pdf_folder):
    if filename.endswith(".pdf"):
        pdf_path = os.path.join(pdf_folder, filename)
        extracted_text = process_pdf(pdf_path, output_folder, file_prefix)

print("すべてのPDFファイルからのテキスト抽出が完了しました。")
# Out:
# 1 has been written to iryohi_md_9_page_1.md
# 2 has been written to iryohi_md_9_page_2.md
# 3 has been written to iryohi_md_9_page_3.md
# 4 has been written to iryohi_md_9_page_4.md
# 5 has been written to iryohi_md_9_page_5.md
# 6 has been written to iryohi_md_9_page_6.md
# 7 has been written to iryohi_md_9_page_7.md
# 8 has been written to iryohi_md_9_page_8.md
# 9 has been written to iryohi_md_9_page_9.md
# 10 has been written to iryohi_md_9_page_10.md
# 11 has been written to iryohi_md_9_page_11.md
# 12 has been written to iryohi_md_9_page_12.md
# 13 has been written to iryohi_md_9_page_13.md
# 14 has been written to iryohi_md_9_page_14.md
# 15 has been written to iryohi_md_9_page_15.md
# 16 has been written to iryohi_md_9_page_16.md
# 17 has been written to iryohi_md_9_page_17.md
# 18 has been written to iryohi_md_9_page_18.md
# 19 has been written to iryohi_md_9_page_19.md
# 20 has been written to iryohi_md_9_page_20.md
# 21 has been written to iryohi_md_9_page_21.md
# ...

# %%
# !pip install markitdown

# %%
##### MarkItDown（OCR ３回目）

from markitdown import MarkItDown
from openai import OpenAI
import os


def extract_content_from_pdf(file_path):
    """
    PDFファイルからテキストと表を抽出します。
    """
    client = OpenAI(api_key=KEY)
    model = "gpt-4o-2024-11-20"
    md = MarkItDown(llm_client=client, llm_model=model)
    result = md.convert(file_path)
    return result.text_content


# PDFファイルが含まれるフォルダ
pdf_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents"
# 抽出されたテキストファイルを保存するフォルダ
output_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text"

# 出力フォルダが存在しない場合は作成
os.makedirs(output_folder, exist_ok=True)

# PDFフォルダ内のすべてのファイルをループ
for filename in os.listdir(pdf_folder):
    if filename.endswith(".pdf"):
        pdf_path = os.path.join(pdf_folder, filename)
        extracted_text = extract_content_from_pdf(pdf_path)

        # 抽出されたテキストをPDFファイルと同じ名前のテキストファイルに保存
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.txt")
        with open(output_path, "w", encoding="utf-8") as file:
            file.write(extracted_text)

print("すべてのPDFファイルからのテキスト抽出が完了しました。")
# Out:
# WARNING:pdfminer.pdfpage:The PDF <_io.BufferedReader name='/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents/15.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
# WARNING:pdfminer.pdftypes:Data-loss while decompressing corrupted data
# WARNING:pdfminer.pdfpage:The PDF <_io.BufferedReader name='/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents/19.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
# WARNING:pdfminer.pdftypes:Data-loss while decompressing corrupted data
# ...

# %% [markdown]
# # OCR４回目

# %%
pip install azure-ai-formrecognizer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.4/301.4 kB 646.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.9/198.9 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 6.8 MB/s eta 0:00:00
# ...

# %%
pip install azure-ai-documentintelligence==1.0.0b4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 4.1 MB/s eta 0:00:00
# ...

# %%
pip install azure-storage-blob
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.4/408.4 kB 8.7 MB/s eta 0:00:00
# ...

# %%
pip install azure-storage-blob azure-ai-formrecognizer

# %%
##### Azure AI Document（OCR ４回目）

from azure.ai.formrecognizer import DocumentAnalysisClient
from azure.core.credentials import AzureKeyCredential
import os
from azure.storage.blob import BlobServiceClient

# Azure AI Document Intelligenceのクライアントを設定
client = DocumentAnalysisClient(endpoint=endpoint, credential=AzureKeyCredential(key))

# PDFファイルが含まれるフォルダ
pdf_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents"
# 抽出されたテキストファイルを保存するフォルダ
output_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text"

# 出力フォルダが存在しない場合は作成
os.makedirs(output_folder, exist_ok=True)

# Azure Blob Storageの設定


# PDFフォルダ内のすべてのファイルをループ
for filename in os.listdir(pdf_folder):
    if filename.endswith(".pdf"):
        pdf_path = os.path.join(pdf_folder, filename)

        # Blobストリームの取得
        blob_client = blob_service_client.get_blob_client(container=container_name, blob=filename)
        stream = blob_client.download_blob().readall()

        document_analysis_client = DocumentAnalysisClient(endpoint, AzureKeyCredential(key))

        # OCRの実行
        poller = document_analysis_client.begin_analyze_document("prebuilt-read", stream)
        result = poller.result()

        # 抽出されたテキストを文字列として取得
        extracted_text = ""
        for page in result.pages:
            for line in page.lines:
                extracted_text += line.content + "\n"

        # 抽出されたテキストをPDFファイルと同じ名前のテキストファイルに保存
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.txt")
        with open(output_path, "w", encoding="utf-8") as file:
            file.write(extracted_text)

print("すべてのPDFファイルからのテキスト抽出が完了しました。")
# Out:
# WARNING:azure.core.pipeline.transport._requests_basic:Incomplete download: ('Connection broken: IncompleteRead(270336 bytes read, 16308032 more expected)', IncompleteRead(270336 bytes read, 16308032 more expected))
# すべてのPDFファイルからのテキスト抽出が完了しました。

# %%
##### Azure AI Document（OCR ４回目その２）精度は良さそう。ただしHTML形式になる。

from azure.ai.formrecognizer import DocumentAnalysisClient
from azure.core.credentials import AzureKeyCredential
import os
from azure.storage.blob import BlobServiceClient

from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import (
    AnalyzeDocumentRequest,
    ContentFormat,
    AnalyzeResult,
)


# Azure AI Document Intelligenceのクライアントを設定
client = DocumentIntelligenceClient(endpoint=endpoint, credential=AzureKeyCredential(key))

# PDFファイルが含まれるフォルダ
pdf_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents"
# 抽出されたテキストファイルを保存するフォルダ
output_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text"

# 出力フォルダが存在しない場合は作成
os.makedirs(output_folder, exist_ok=True)

# Azure Blob Storageの設定


print("すべてのPDFファイルからのテキスト抽出が完了しました。")
# Out:
# WARNING:azure.core.pipeline.transport._requests_basic:Incomplete download: ('Connection broken: IncompleteRead(2179072 bytes read, 12386417 more expected)', IncompleteRead(2179072 bytes read, 12386417 more expected))
# すべてのPDFファイルからのテキスト抽出が完了しました。

# %% [markdown]
# # OCR５回目

# %%
# !pip install yomitoku
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 51.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 84.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 55.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 25.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.2 MB/s eta 0:00:00
# ...

# %%
# !pip freeze | grep yomitoku
# Out:
# yomitoku==0.7.1

# %%
# !apt update && apt install -y poppler-utils
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 21 packages can be upgraded. Run 'apt list --upgradable' to see them.
# ...

# %%
# !pip install pdf2image

# %%
##### Yomitoku(OCR５回目）https://zenn.dev/kun432/scraps/9a4773cc173627

import fitz  # PyMuPDF
import os

# フォルダ内のPDFファイルを画像に変換する関数
def convert_pdf_to_image(pdf_path, output_dir_path):
    os.makedirs(output_dir_path, exist_ok=True)
    pdf_document = fitz.open(pdf_path)
    base_name = os.path.basename(pdf_path).replace('.pdf', '')

    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        output_path = f"{output_dir_path}/{base_name}_page_{page_num + 1}.png"
        pix.save(output_path)
        print(f"Saved: {output_path}")

# PDFファイルが格納されているフォルダと出力先フォルダ
pdf_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents"
output_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png"

# 1.pdfから19.pdfまでのPDFファイルを処理
for i in range(1, 20):
    pdf_file = f"{pdf_folder}/{i}.pdf"
    convert_pdf_to_image(pdf_file, output_folder)
# Out:
# Saved: /content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png/1_page_1.png
# Saved: /content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png/1_page_2.png
# Saved: /content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png/1_page_3.png
# Saved: /content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png/1_page_4.png
# Saved: /content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png/1_page_5.png
# Saved: /content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png/1_page_6.png
# Saved: /content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png/1_page_7.png
# Saved: /content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png/1_page_8.png
# Saved: /content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png/1_page_9.png
# Saved: /content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png/1_page_10.png
# ...

# %%
import subprocess
subprocess.run(["yomitoku", "/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png", "-f", "md", "-o", "/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text2", "-v"])
#subprocess.run(["yomitoku", "/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png", "-f", "md", "-o", "/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text2", "-v", "--figure"])
# Out:
# CompletedProcess(args=['yomitoku', '/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png', '-f', 'md', '-o', '/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text2', '-v'], returncode=0)

# %% [markdown]
# # OCR６回目

# %%
# Genimi（OCR６回目）

import argparse
import os
import re
from pathlib import Path
import google.generativeai as genai

import openpyxl
from openpyxl.styles import Font, PatternFill, Border, Side, Alignment
from openpyxl.utils import get_column_letter

import mimetypes

def get_gemini_api_key():
    """環境変数からGemini APIキーを取得する"""
    api_key = GKEY #os.environ.get("GEMINI_API_KEY")
    if not api_key:
        print("エラー: 環境変数 'GEMINI_API_KEY' が設定されていません。設定してください。")
        exit(1)
    return api_key

def get_mime_type(filepath):
    """ファイルの拡張子からMIMEタイプを取得する"""
    mime_type, _ = mimetypes.guess_type(filepath)
    if not mime_type:
        raise ValueError(f"対応していないファイル形式です: {filepath}")
    return mime_type

def read_file(filepath):
    """ファイルを読み込み、バイナリデータを返す"""
    mime_type = get_mime_type(filepath)
    with open(filepath, "rb") as f:
        return f.read(), mime_type

def create_prompt(mime_type, outfiletype):
    """プロンプトを作成する"""
    file_type = "PDF" if mime_type == "application/pdf" else "画像"
    output_format = {
      "txt": "プレーンテキスト",
      "md": "マークダウン",
      "csv": "CSV",
      "html": "HTML",
      "xlsx": "マークダウン",
    }.get(outfiletype, "プレーンテキスト")
    prompt = f"この{file_type}を読み込んで{output_format}形式で出力してください。"
    if outfiletype == "html":
      prompt += "表はstyleを指定して見やすくしてください。"
    return prompt

def extract_file_content(response_text):
    """Geminiのレスポンスからコードブロック＝ファイル内容を抽出する"""
    # コードブロックの正規表現パターン
    pattern = r'```(?:[^\n]*\n)?([\s\S]*?)(?:```|$)'

    # 最初のコードブロックを検索
    match = re.search(pattern, response_text)

    if match:
        # コードブロックの内容を返す
        return match.group(1).strip()
    else:
        # コードブロックが見つからない場合はNoneを返す
        return None

def markdown_to_excel(markdown_text, excel_file):
    """マークダウン形式テキストからExcelファイルを生成する"""
    wb = openpyxl.Workbook()
    sheet = wb.active
    row_num = 1
    table_data = []
    in_table = False

    for line in markdown_text.splitlines():
        line = line.strip()

        if line.startswith("#"):
            if in_table:
                output_table(sheet, table_data, row_num)
                row_num += len(table_data) + 1
                table_data = []
                in_table = False
            header_level = len(line.split(" ")[0])
            header_text = line[header_level+1:].strip()
            cell = sheet.cell(row=row_num, column=1, value=header_text)
            cell.font = Font(bold=True)
            row_num += 1
        elif line.startswith("|"):
            in_table = True
            row_data = [cell.strip() for cell in line.split("|")[1:-1]]
            row_data = [cell.replace("<br>", "\n").replace("<BR>", "\n") for cell in row_data]
            if not is_markdown_table_separator(row_data):
                table_data.append(row_data)
        else:
            if in_table:
                output_table(sheet, table_data, row_num)
                row_num += len(table_data) + 1
                table_data = []
                in_table = False
            if line:
               cell = sheet.cell(row=row_num, column=1, value=line)
               row_num += 1

    if in_table:
        output_table(sheet, table_data, row_num)

    adjust_column_width(sheet)
    wb.save(excel_file)

def output_table(sheet, table_data, start_row):
    """マークダウン形式テキストの表をExcelファイルを書きこむ"""
    if not table_data:
        return

    header = table_data[0]
    data = table_data[1:]

    header_row = start_row
    data_start_row = start_row + 1

    # ヘッダー出力
    for col, header_text in enumerate(header, start=2):
        cell = sheet.cell(row=header_row, column=col, value=header_text)
        cell.font = Font(bold=True)
        cell.fill = PatternFill(start_color="EBF1DE", end_color="EBF1DE", fill_type="solid")
        cell.alignment = Alignment(horizontal="center", vertical="center")

    # データ出力
    for row, row_data in enumerate(data, start=data_start_row):
        for col, cell_value in enumerate(row_data, start=2):
            cell = sheet.cell(row=row, column=col, value=cell_value)
            cell.alignment = Alignment(horizontal="center", vertical="center",wrap_text=True)

    # 罫線設定
    border = Border(left=Side(style='thin'), right=Side(style='thin'), top=Side(style='thin'), bottom=Side(style='thin'))
    for row in range(start_row,start_row + len(table_data)):
        for col in range(2,len(header)+2):
            sheet.cell(row=row,column=col).border = border

def is_markdown_table_separator(strings):
    """マークダウン形式テキストの表のヘッダとデータの区切り行を判定する"""
    pattern = r'^(:?-+):?(:?-*)$'

    # すべての文字列が条件を満たすか判定
    return all(re.fullmatch(pattern, s) for s in strings)

def adjust_column_width(sheet):
    """Excelファイルの列の幅を調整する。B列以降、最大50。"""
    MAX_COLUMN_WIDTH = 50

    for col in range(2, sheet.max_column + 1):
        max_length = 0
        for cell in sheet[get_column_letter(col)]:
            try:
                if len(str(cell.value)) > max_length:
                    max_length = len(str(cell.value))
            except:
                pass
        adjusted_width = (max_length + 2)
        if adjusted_width > MAX_COLUMN_WIDTH:
            adjusted_width = MAX_COLUMN_WIDTH
        sheet.column_dimensions[get_column_letter(col)].width = adjusted_width

def process_response(response, outfiletype, outfile):
    """Geminiのレスポンスを処理し、指定された形式でファイルに出力する"""
    response_text = response.text
    file_content = extract_file_content(response_text)
    if file_content == None:
        file_content = response_text

    if outfiletype == "xlsx":
        markdown_to_excel(file_content, outfile)
        with open(outfile + ".temp.md", "w", encoding="utf-8") as f:
            f.write(file_content)
    elif outfile:
        if outfiletype == "csv":
            import locale
            output_encoding = locale.getpreferredencoding()
        else:
            output_encoding = "utf-8"
        with open(outfile, "w", encoding=output_encoding) as f:
            f.write(file_content)
    else:
        print(file_content)


def main():
    """メイン処理"""
    parser = argparse.ArgumentParser(description="PDF/画像ファイルをOCRして出力します。")
    parser.add_argument("-infile", required=True, help="入力ファイル (PDFまたは画像)")
    parser.add_argument("-outfile", help="出力ファイル (省略時は標準出力)")
    parser.add_argument("-outfiletype", help="出力ファイル形式 (txt, md, csv, html, xlsx) (省略時は出力ファイルの拡張子)")
    args = parser.parse_args()

    infile = args.infile.lower()
    outfile = args.outfile
    outfiletype = args.outfiletype

    if outfile:
      outfile = outfile.lower()
      if not outfiletype:
         outfiletype = Path(outfile).suffix.lower()[1:]
    else:
      if not outfiletype:
        outfiletype = "txt"

    print(f"入力ファイル: {infile}")
    print(f"出力ファイル: {outfile if outfile else '標準出力'}")
    print(f"出力ファイル形式: {outfiletype}")

    if not outfile and outfiletype == "xlsx":
        print("エラー: 標準出力に xlsx 形式はサポートされていません。")
        exit(1)

    try:
        api_key = get_gemini_api_key()
        genai.configure(api_key=api_key)

        model = genai.GenerativeModel("gemini-2.0-flash-exp")
        file_data, mime_type = read_file(infile)

        prompt = create_prompt(mime_type, outfiletype)
        print(f"Geminiプロンプト: {prompt}")

        content = [{'mime_type': mime_type, 'data': file_data}, prompt]
        response = model.generate_content(content)
        print("Geminiレスポンス:")
        print(response)

        process_response(response, outfiletype, outfile)

    except FileNotFoundError as e:
        print(f"ファイルが見つかりません: {e}")
    except ValueError as e:
        print(f"無効な入力です: {e}")
    except Exception as e:
        print(f"不明なエラーが発生しました: {e}")



# フォルダ内のPDFファイルを画像に変換する関数
def convert_pdf_to_image(pdf_path, output_dir_path):
    os.makedirs(output_dir_path, exist_ok=True)
    pdf_document = fitz.open(pdf_path)
    base_name = os.path.basename(pdf_path).replace('.pdf', '')

    model = genai.GenerativeModel("gemini-2.0-flash-exp")
    file_data, mime_type = read_file(pdf_path)

    prompt = create_prompt(mime_type, "md")
    print(f"Geminiプロンプト: {prompt}")

    content = [{'mime_type': mime_type, 'data': file_data}, prompt]
    response = model.generate_content(content)
    print("Geminiレスポンス:")
    print(response)

    process_response(response, "md", output_dir_path)


# PDFファイルが格納されているフォルダと出力先フォルダ
pdf_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents"
output_folder = "/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_png"

# 1.pdfから19.pdfまでのPDFファイルを処理
for i in range(1, 20):
    pdf_file = f"{pdf_folder}/{i}.pdf"
    convert_pdf_to_image(pdf_file, output_folder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-440d61f2b0cf> in <cell line: 0>()
#     266 for i in range(1, 20):
#     267     pdf_file = f"{pdf_folder}/{i}.pdf"
# --> 268     convert_pdf_to_image(pdf_file, output_folder)
#
# <ipython-input-9-440d61f2b0cf> in convert_pdf_to_image(pdf_path, output_dir_path)
#     242 def convert_pdf_to_image(pdf_path, output_dir_path):
#     243     os.makedirs(output_dir_path, exist_ok=True)
# --> 244     pdf_document = fitz.open(pdf_path)
#     245     base_name = os.path.basename(pdf_path).replace('.pdf', '')
#     246
#
# NameError: name 'fitz' is not defined

# %% [markdown]
# # OCRファイルの前処理

# %%
import os


def convert_files_to_utf8(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".txt"):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, "r", encoding="shift_jis") as f:
                        content = f.read()
                    with open(file_path, "w", encoding="utf-8") as f:
                        f.write(content)
                    print(f"Converted {file_path} to UTF-8")
                except Exception as e:
                    print(f"Error converting {file_path}: {e}")


convert_files_to_utf8("/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text")

# %% [markdown]
# 2. text_process.pyにより､preprocessed_novelsフォルダに前処理後のテキストファイルを格納

# %%
# !ls -la /content/drive/My\ Drive/Colab\ Notebooks/14.第３回金融データ活用チャレンジ/text_preprocess.py
# Out:
# -rw------- 1 root root 5210 Jan 26 07:22 '/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/text_preprocess.py'

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ')

# %%
# !python text_preprocess.py /content/drive/My\ Drive/Colab\ Notebooks/14.第３回金融データ活用チャレンジ/documents_text /content/drive/My\ Drive/Colab\ Notebooks/14.第３回金融データ活用チャレンジ/preprocessed_documents
# Out:
# 処理完了: 15.txt -> 15.txt
# 処理完了: 8.txt -> 8.txt
# 処理完了: 16.txt -> 16.txt
# 処理完了: 10.txt -> 10.txt
# 処理完了: 11.txt -> 11.txt
# 処理完了: 14.txt -> 14.txt
# 処理完了: 13.txt -> 13.txt
# 処理完了: 12.txt -> 12.txt
# 処理完了: 19.txt -> 19.txt
# 処理完了: 6.txt -> 6.txt
# 処理完了: 18.txt -> 18.txt
# 処理完了: 7.txt -> 7.txt
# 処理完了: 5.txt -> 5.txt
# 処理完了: 4.txt -> 4.txt
# 処理完了: 1.txt -> 1.txt
# 処理完了: 2.txt -> 2.txt
# 処理完了: 3.txt -> 3.txt
# 処理完了: 9.txt -> 9.txt
# 処理完了: 17.txt -> 17.txt

# %% [markdown]
# # Enbedding

# %%
# Enbedding①(Text)

import csv
import os
import re
import textwrap
import time
from datetime import datetime

import openai
import pandas as pd
from langchain.document_loaders import DirectoryLoader, TextLoader


# OpenAI APIの初期化
openai.api_key = KEY

# 報告書ファイルの読み込み
loader = DirectoryLoader("/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text", glob="**/*.md", loader_cls=TextLoader)
#loader = DirectoryLoader("/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/preprocessed_documents", glob="**/*.txt", loader_cls=TextLoader)
docs = loader.load()

# 報告書をディクショナリに格納
text = {doc.metadata["source"].split("/")[-1]: doc.page_content for doc in docs}


# ------------------------------------------------------------------------

from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter.from_tiktoken_encoder(separator = "\n\n", chunk_size=1000, chunk_overlap=0) # "\n\n"
texts = text_splitter.split_documents(docs)

print(len(texts))


# ------------------------------------------------------------------------

from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(api_key=KEY, model="text-embedding-3-small")
#db = Chroma.from_documents(docs, embeddings)

import time

# バッチ処理(RateLimitを超過した場合はスキップするため)
batch_size = 5
for i in range(0, len(texts), batch_size):
    batch_docs = texts[i:i + batch_size]
    success = False
    retries = 3
    while not success and retries > 0:
        try:
            db = Chroma.from_documents(batch_docs, embeddings)
            success = True
        except openai.error.RateLimitError as e: ##### except openai.RateLimitError as e:
            print(f"Rate limit error: {e}")
            retries -= 1
            time.sleep(60)  # 60秒待機してリトライ
        except Exception as e:
            print(f"An error occurred: {e}")
            break

# %%
pip install unstructured
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 21.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 64.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.1/167.1 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 9.1 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=2a9a4c089cb6aa366443ccb746443cd44217e106637ac94ed463cc6322399c1a
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# ...

# %%
# Enbedding②(Markdown)

from langchain_community.document_loaders import UnstructuredMarkdownLoader
import pandas as pd
import csv
import os
import re
import textwrap
import time
from datetime import datetime

# データを格納するための空のリストを初期化
texts = []

# 1.mdから19.mdまでのファイルをループで処理
for i in range(1, 20):
    markdown_path = f"/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/documents_text/{i}.md"
    loader = UnstructuredMarkdownLoader(markdown_path, mode="paged")
    data = loader.load()
    texts.extend(data)

print(f"Number of documents: {len(texts)}\\n")
# Out:
# WARNING:/usr/local/lib/python3.11/dist-packages/langchain_community/document_loaders/unstructured.py:`mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# WARNING:/usr/local/lib/python3.11/dist-packages/langchain_community/document_loaders/unstructured.py:`mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# WARNING:/usr/local/lib/python3.11/dist-packages/langchain_community/document_loaders/unstructured.py:`mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# ...

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
import openai

embeddings = OpenAIEmbeddings(api_key=KEY, model="text-embedding-3-small")
#db = Chroma.from_documents(docs, embeddings)

import time

# バッチ処理(RateLimitを超過した場合はスキップするため)
batch_size = 5
for i in range(0, len(texts), batch_size):
    batch_docs = texts[i:i + batch_size]
    success = False
    retries = 3
    while not success and retries > 0:
        try:
            db = Chroma.from_documents(batch_docs, embeddings)
            success = True
        except openai.RateLimitError as e: ##### except openai.RateLimitError as e:
            print(f"Rate limit error: {e}")
            retries -= 1
            time.sleep(60)  # 60秒待機してリトライ
        except Exception as e:
            print(f"An error occurred: {e}")
            break
# Out:
# An error occurred: Expected metadata value to be a str, int, float or bool, got ['jpn'] which is a list in upsert.
#
# Try filtering complex metadata from the document using langchain_community.vectorstores.utils.filter_complex_metadata.
# An error occurred: Expected metadata value to be a str, int, float or bool, got ['jpn'] which is a list in upsert.
#
# Try filtering complex metadata from the document using langchain_community.vectorstores.utils.filter_complex_metadata.
# An error occurred: Expected metadata value to be a str, int, float or bool, got ['jpn'] which is a list in upsert.
#
# Try filtering complex metadata from the document using langchain_community.vectorstores.utils.filter_complex_metadata.
# An error occurred: Expected metadata value to be a str, int, float or bool, got ['jpn'] which is a list in upsert.
#
# Try filtering complex metadata from the document using langchain_community.vectorstores.utils.filter_complex_metadata.

# %% [markdown]
# # Predict１回目

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI

prompt = ChatPromptTemplate.from_template('''\
以下の文脈だけを踏まえて質問に回答してください。回答は改行せずに一行で、50文字以内で、また情報が含まれていないと回答する場合には代わりに「分かりません」と答えて下さい。
あなたは企業の統合報告書の内容を分析し、その内容を元に質問に回答する専門家です。以下のプロセスと指示に従って、メタ認知を駆使しながら推測を行ってください。
  # 回答プロセス
  1. すべての思考プロセスを<thinking>タグで囲み、複数の角度やアプローチを探ってください。
  2. 解決策を明確なステップに分解し、<step>タグ内に記述してください。15ステップから始め、複雑な問題の場合は追加のステップを要求してください。
  3. 各ステップの後に<count>タグを使用して、残りのステップ数を示してください。0に達したら停止します。
  4. 中間結果や反省に基づいて推論を継続的に調整し、進行に応じて戦略を適応させてください。
  5. <reflection>タグを使用して定期的に進捗を評価してください。推論プロセスについて批判的かつ正直に評価してください。
  6. 各反省の後に、0.0から1.0の間の品質スコアを<reward>タグを使用して割り当ててください。このスコアを使用してアプローチを導いてください：
      - 0.8以上：現在のアプローチを継続
      - 0.5-0.7：軽微な調整を検討
      - 0.5未満：別のアプローチを試すことを真剣に検討
  7. 不確かな場合や報酬スコアが低い場合は、バックトラックして別のアプローチを試み、<thinking>タグ内で決定を説明してください。
  8. 可能な場合は複数の解決策を個別に探り、反省で各アプローチを比較してください。
  9. 思考をメモ帳として使用し、すべての計算と推論を明示的に書き出してください。
  10.最終的な答え（質問に対する答え）は、明確で簡潔に15文字以内で要約して<answer>タグ内で提供してください。「報酬スコア」が0.9未満の場合には最終的な答えは「分かりません」にして下さい。

文脈: """
{context}
"""

質問: {question}
''')

model = ChatOpenAI(api_key=KEY, model="gpt-4o-mini", temperature=0)
retriever = db.as_retriever()

chain = {
    "question": RunnablePassthrough(),
    "context": retriever,
} | prompt | model | StrOutputParser()

query = "高松コンストラクショングループの2025年3月期の受注高の計画は前期比何倍か、小数第三位を四捨五入し答えてください。。"
chain.invoke(query)
# Out:
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# ...

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI

def predict_novel(query):
  prompt = ChatPromptTemplate.from_template('''\
""
あなたは企業の統合報告書の内容を分析し、その内容を元に質問に回答する専門家です。以下のプロセスと指示に従って、メタ認知を駆使しながら推測を行ってください。
  # 回答プロセス
  1. すべての思考プロセスを<thinking>タグで囲み、複数の角度やアプローチを探ってください。
  2. 解決策を明確なステップに分解し、<step>タグ内に記述してください。15ステップから始め、複雑な問題の場合は追加のステップを要求してください。
  3. 各ステップの後に<count>タグを使用して、残りのステップ数を示してください。0に達したら停止します。
  4. 中間結果や反省に基づいて推論を継続的に調整し、進行に応じて戦略を適応させてください。
  5. <reflection>タグを使用して定期的に進捗を評価してください。推論プロセスについて批判的かつ正直に評価してください。
  6. 各反省の後に、0.0から1.0の間の品質スコアを<reward>タグを使用して割り当ててください。このスコアを使用してアプローチを導いてください：
      - 0.8以上：現在のアプローチを継続
      - 0.5-0.7：軽微な調整を検討
      - 0.5未満：別のアプローチを試すことを真剣に検討
  7. 不確かな場合や報酬スコアが低い場合は、バックトラックして別のアプローチを試み、<thinking>タグ内で決定を説明してください。
  8. 可能な場合は複数の解決策を個別に探り、反省で各アプローチを比較してください。
  9. 思考をメモ帳として使用し、すべての計算と推論を明示的に書き出してください。
  10.最終的な答え（質問に対する答え）は、明確で簡潔に15文字以内で要約して<answer>タグ内で提供してください。「報酬スコア」が0.9未満の場合には最終的な答えは「分かりません」にして下さい。

文脈: """
{context}
"""

質問: {question}
''')

  model = ChatOpenAI(api_key=KEY, model="gpt-4o-mini", temperature=0)
  retriever = db.as_retriever()

  chain = {
      "question": RunnablePassthrough(),
      "context": retriever,
  } | prompt | model | StrOutputParser()

  #print(chain.invoke(query))
  return chain.invoke(query)


"""
def predict_novel(query):
  response = client.chat.completions.create(
      model="gpt-4o-mini",
      messages=[
        {
            "role": "system",
            "content": "あなたは企業の統合報告書の内容を分析し、その内容を元に質問に回答する専門家です。以下のプロセスと指示に従って、メタ認知を駆使しながら推測を行ってください。" ,
        },
        {
            "role": "user",
            "content":query,
        },
      ],
        max_tokens=8192,
        temperature=1.0
    )
  print(response.choices[0].message.content)
  return response.choices[0].message.content
"""

"""
def extract_filename(text):
    # まず<answer>タグ内のテキストを探す
    answer_match = re.search(r"<answer>(.*?)(</answer>|$)", text, re.DOTALL | re.IGNORECASE)
    if answer_match:
        answer_text = answer_match.group(1).strip()
    else:
        answer_text = text

    # それでもマッチしない場合は "不明.txt" を返す
    return answer_text
"""
def extract_filename(text):
    # <answer>タグが存在するか確認
    answer_tags = list(re.finditer(r"<answer>", text, re.IGNORECASE))
    answer_end_tags = list(re.finditer(r"</answer>", text, re.IGNORECASE))
    #print(answer_tags)

    if answer_tags and answer_end_tags:
        # 最後の<answer>タグと対応する</answer>タグを取得
        last_answer_tag = answer_tags[-1]
        last_answer_end_tag = answer_end_tags[-1]

        # <answer>タグの直後からの文字列を取得
        start_index = last_answer_tag.end()
        finish_index = last_answer_end_tag.start()
        answer_text = text[start_index:finish_index].strip()
        return answer_text

    # <answer>タグが存在しない場合
    return "分かりません"


# 開始位置を設定（デフォルトは1、必要に応じて変更可能）
start_index = 1

# 質問データの読み込み
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/query.csv")

# 現在の日付と時刻を取得
current_datetime = datetime.now()
date_time_folder = current_datetime.strftime("%Y%m%d%H%M")

# 出力ディレクトリのパスを作成
output_dir = f"/content/drive/My Drive/Colab Notebooks/14.第３回金融データ活用チャレンジ/output/{date_time_folder}"

# ディレクトリが存在しない場合は作成
os.makedirs(output_dir, exist_ok=True)

# 結果を保存するファイルのパス
output_file = os.path.join(output_dir, "predictions.csv")


# バッチ単位ずつ処理し、結果をファイルに書き込む関数
def process_and_write_batch(batch, writer, start_index):  # def process_and_write_batch(batch, writer, start_index, novels):
    for i, (index, query) in enumerate(batch.items(), start=start_index):
        try:
            result = extract_filename(predict_novel(query))
            #result = predict_novel(query)
            #writer.writerow([i + 1, query, result])
            writer.writerow([i, result])
            print(f"Processed question {i}: {result}")
        except Exception as e:
            print(f"Error processing query {i}: {query}")
            print(f"Error: {e}")
            writer.writerow([i, query, "エラー発生"])


# バッチサイズと総バッチ数の設定
batch_size = 1
total_questions = len(df)
total_batches = (total_questions - start_index + 1 + batch_size - 1) // batch_size

# ファイルを開いて処理を開始
mode = "a" if os.path.exists(output_file) else "w"
with open(output_file, mode, newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    #if mode == "w":
        #writer.writerow(["index", "file"])  # ヘッダーを書き込む

    # バッチ処理の部分
    for i in range(total_batches):
        batch_start = start_index + i * batch_size - 1
        batch_end = min(batch_start + batch_size, total_questions)
        batch = df["problem"][batch_start:batch_end]

        #print(f"Processing batch {i+1}/{total_batches} (questions {batch_start+1}-{batch_end})")
        process_and_write_batch(batch, writer, batch_start) #process_and_write_batch(batch, writer, batch_start, novels)

        # ファイルをフラッシュして確実に書き込む
        csvfile.flush()

        # API制限を考慮して、バッチ間に少し待機時間を入れる
        #if i < total_batches - 1:
            #print("Waiting for 1 seconds before the next batch...")
        #    time.sleep(1)  # 1秒待機

print(f"推論結果が生成され、{output_file}に保存されました。")
# Out:
# Error processing query 0: 高松コンストラクショングループの2025年3月期の受注高の計画は前期比何倍か、小数第三位を四捨五入し答えてください。
# Error: name 'db' is not defined
# Error processing query 1: 株式会社キッツの取締役の報酬のうち株式報酬の割合は何％？
# Error: name 'db' is not defined
# Error processing query 2: グローリーが2024年の統合報告書の中で、研究開発費が増加した理由として挙げている事由は何？
# Error: name 'db' is not defined
# Error processing query 3: 高松コンストラクショングループの2024年3月期の非常勤監査役は何人？
# Error: name 'db' is not defined
# Error processing query 4: 2023年で即席めんの一人当たりの年間消費量が最も多い国はどこか。
# Error: name 'db' is not defined
# Error processing query 5: 株式会社キッツで2023年度のデジタル教育受講者数は何人？
# Error: name 'db' is not defined
# Error processing query 6: 2023年度の日清食品ホールディングスの海外事業において、コア営業利益が2番目に高い地域に含まれる国として記載がある国名を全て教えてください。
# Error: name 'db' is not defined
# Error processing query 7: 株式会社キッツの2023年度売上高構成比が2番目に高い事業の製造・販売会社を全て上げよ。（回答には株式会社も含めること）
# Error: name 'db' is not defined
# Error processing query 8: IHIの2023年度の資源・エネルギー・環境事業領域の営業利益が過去最高を記録した要因として挙げているものはなにか
# Error: name 'db' is not defined
# ...

# %%
import zipfile

# submitフォルダのパスを作成
submit_folder = os.path.join("submit", "submit")
os.makedirs(submit_folder, exist_ok=True)

# predictions.csvファイルをsubmitフォルダにコピー
submit_file_path = os.path.join(submit_folder, "predictions.csv")
os.rename(output_file, submit_file_path)

# submitフォルダをZIPファイルに圧縮
with zipfile.ZipFile("submit.zip", 'w') as zipf:
    for root, dirs, files in os.walk("submit"):
        for file in files:
            zipf.write(os.path.join(root, file))

print("predictions.csvがsubmit.zipのsubmitフォルダの中に作成されました。")
# Out:
# predictions.csvがsubmit.zipのsubmitフォルダの中に作成されました。

# %% [markdown]
# # query.csv内の各質問がどのファイルを参照すればよいかを推論

# %%
# GPT + RAG -> 採用（OCR１回目＋前処理）！！！

import csv
import os
import re
import textwrap
import time
from datetime import datetime

import google.generativeai as genai
import pandas as pd
from dotenv import load_dotenv
from langchain_community.document_loaders import DirectoryLoader, TextLoader

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI

"""
# .envファイルから環境変数を読み込む
load_dotenv()

# Google API Keyを環境変数から取得
google_api_key = GKEY #os.getenv("GOOGLE_API_KEY")

# Geminiモデルの初期化
genai.configure(api_key=google_api_key)

# Create the model
generation_config = {
    "temperature": 1.0,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
    model_name="gemini-1.5-pro-002",
    generation_config=generation_config,
)
"""

model = ChatOpenAI(api_key=KEY, model="gpt-4o-mini", temperature=0)


# 小説ファイルの読み込み
loader = DirectoryLoader("/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/preprocessed_documents", glob="**/*.txt", loader_cls=TextLoader)
docs = loader.load()

# 内容をディクショナリに格納
novels = {doc.metadata["source"].split("/")[-1]: doc.page_content for doc in docs}


def predict_novel(query):
    prompt = ChatPromptTemplate.from_template('''\

## 役割
あなたは企業の統合報告書の内容を分析し、その内容を元に質問に回答する専門家です。以下のプロセスと指示に従って、メタ認知を駆使しながら推測を行ってください。

## 回答プロセス
1. すべての思考プロセスを<thinking>タグで囲み、複数の角度やアプローチを探ってください。
2. 解決策を明確なステップに分解し、<step>タグ内に記述してください。20ステップから始め、複雑な問題の場合は追加のステップを要求してください。
3. 各ステップの後に<count>タグを使用して、残りのステップ数を示してください。0に達したら停止します。
4. 中間結果や反省に基づいて推論を継続的に調整し、進行に応じて戦略を適応させてください。
5. <reflection>タグを使用して定期的に進捗を評価してください。推論プロセスについて批判的かつ正直に評価してください。
6. 各反省の後に、0.0から1.0の間の品質スコアを<reward>タグを使用して割り当ててください。このスコアを使用してアプローチを導いてください：
    - 0.8以上：現在のアプローチを継続
    - 0.5-0.7：軽微な調整を検討
    - 0.5未満：別のアプローチを試すことを真剣に検討
7. 不確かな場合や報酬スコアが低い場合は、バックトラックして別のアプローチを試み、<thinking>タグ内で決定を説明してください。
8. 可能な場合は複数の解決策を個別に探り、反省で各アプローチを比較してください。
9. 思考をメモ帳として使用し、すべての計算と推論を明示的に書き出してください。
10. 最終的な答え（ファイル名）を<answer>タグ内で提供し、明確で簡潔な要約を示してください。
11. 全体的な解決策について最終的な反省を行い、効果、課題、解決策について議論し、最終的な報酬スコアを割り当ててください。

## 指示
1. **txtファイルの概要確認**: 以下に与えられたファイルのタイトルと内容を確認します。各ファイルは以下の形式で提供されています：
   'ファイル名': '内容'
2. **質問の分析**: 質問の文脈やキーワードを分析します。
3. **関連性の評価**: 質問に含まれる情報がどのファイルの内容に最も関連があるかを考察します。
4. **推測**: 質問がどのファイルから出題されたと思われるかを明記します。

## Notes
- 与えられたファイルの内容の形式を踏まえて､質問に関連した文章やキーワードがどのファイルに含まれているかを逐一､注意深く確認し､ハルシネーションしないようにしてください｡

## ファイルの内容
各ファイルは１～１９までの数字＋「.txt」で記載されています。各ファイルはそれぞれ独立したある会社の統合報告書です。ファイル名と内容の対応を間違えないように注意してください｡
{context}

質問: {question}

回答プロセスを開始してください。
最終的な回答はファイル名のみを次のように､**<answer>ファイル名.txt</answer>タグ内**として出力してください。''')

    #response = model.generate_content(prompt, generation_config=generation_config)
    #return response.text.strip()

    retriever = db.as_retriever()
    chain = {
        "question": RunnablePassthrough(),
        "context": retriever,
        } | prompt | model | StrOutputParser()

    return chain.invoke(query)


def extract_filename(text, novels):
    # まず<answer>タグ内のテキストを探す
    answer_match = re.search(r"<answer>(.*?)(</answer>|$)", text, re.DOTALL | re.IGNORECASE)
    if answer_match:
        answer_text = answer_match.group(1).strip()
    else:
        answer_text = text

    # novels.keys() 内のファイル名とマッチするか確認
    for novel_filename in novels.keys():
        if novel_filename.lower() in answer_text.lower():
            return novel_filename

    """
    # マッチするものがない場合、テキスト全体から可能性のあるファイル名を探す
    for novel_filename in novels.keys():
        if novel_filename.lower() in text.lower():
            return novel_filename
    """

    # それでもマッチしない場合は "不明.txt" を返す
    return "不明.txt"


# 開始位置を設定（デフォルトは1、必要に応じて変更可能）
start_index = 1

# 質問データの読み込み
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/query.csv")

# 現在の日付と時刻を取得
current_datetime = datetime.now()
date_time_folder = current_datetime.strftime("%Y%m%d%H%M")

# 出力ディレクトリのパスを作成
output_dir = f"/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/output2"

# ディレクトリが存在しない場合は作成
os.makedirs(output_dir, exist_ok=True)

# 結果を保存するファイルのパス
output_file = os.path.join(output_dir, "query_with_predictions.csv")


# バッチ単位ずつ処理し、結果をファイルに書き込む関数
def process_and_write_batch(batch, writer, start_index, novels):
    for i, (index, query) in enumerate(batch.items(), start=start_index):
        try:
            result = extract_filename(predict_novel(query), novels)
            writer.writerow([i + 1, query, result])
            print(f"Processed question {i}: {result}")
        except Exception as e:
            print(f"Error processing query {i}: {query}")
            print(f"Error: {e}")
            writer.writerow([i + 1, query, "エラー発生"])


# バッチサイズと総バッチ数の設定
batch_size = 1
total_questions = len(df)
total_batches = (total_questions - start_index + 1 + batch_size - 1) // batch_size

# ファイルを開いて処理を開始
mode = "a" if os.path.exists(output_file) else "w"
with open(output_file, mode, newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    if mode == "w":
        writer.writerow(["index", "problem", "file"])  # ヘッダーを書き込む

    # バッチ処理の部分
    for i in range(total_batches):
        batch_start = start_index + i * batch_size - 1
        batch_end = min(batch_start + batch_size, total_questions)
        batch = df["problem"][batch_start:batch_end]

        print(f"Processing batch {i+1}/{total_batches} (questions {batch_start+1}-{batch_end})")
        process_and_write_batch(batch, writer, batch_start, novels)

        # ファイルをフラッシュして確実に書き込む
        csvfile.flush()

        # API制限を考慮して、バッチ間に少し待機時間を入れる
        #if i < total_batches - 1:
        #    print("Waiting for 60 seconds before the next batch...")
        #    time.sleep(60)  # 60秒待機

print(f"推論結果が生成され、{output_file}に保存されました。")
# Out:
# Processing batch 1/100 (questions 1-1)
# Processed question 0: 不明.txt
# Processing batch 2/100 (questions 2-2)
# Processed question 1: 不明.txt
# Processing batch 3/100 (questions 3-3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-128-7ec86f0d4e53> in <cell line: 0>()
#     181
#     182         print(f"Processing batch {i+1}/{total_batches} (questions {batch_start+1}-{batch_end})")
# --> 183         process_and_write_batch(batch, writer, batch_start, novels)
#     184
#     185         # ファイルをフラッシュして確実に書き込む
#
# <ipython-input-128-7ec86f0d4e53> in process_and_write_batch(batch, writer, start_index, novels)
#     153     for i, (index, query) in enumerate(batch.items(), start=start_index):
#     154         try:
# --> 155             result = extract_filename(predict_novel(query), novels)
#     156             writer.writerow([i + 1, query, result])
# ...

# %%
# Genimi -> トークンがマキシマムを超える ##### 注意 #####

import csv
import os
import re
import textwrap
import time
from datetime import datetime

import google.generativeai as genai
import pandas as pd
from dotenv import load_dotenv
from langchain_community.document_loaders import DirectoryLoader, TextLoader

# .envファイルから環境変数を読み込む
#load_dotenv()

# Google API Keyを環境変数から取得
google_api_key = GKEY #os.getenv("GOOGLE_API_KEY")

# Geminiモデルの初期化
genai.configure(api_key=google_api_key)

# Create the model
generation_config = {
    "temperature": 1.0,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
    model_name="gemini-1.5-pro-002",
    generation_config=generation_config,
)

# 小説ファイルの読み込み
loader = DirectoryLoader("/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/preprocessed_documents", glob="**/*.txt", loader_cls=TextLoader)
docs = loader.load()

# 小説の内容をディクショナリに格納
novels = {doc.metadata["source"].split("/")[-1]: doc.page_content for doc in docs}


def predict_novel(query):
    prompt = f"""
## 役割
あなたは企業の統合報告書の内容を分析し、その内容を元に質問に回答する専門家です。以下のプロセスと指示に従って、メタ認知を駆使しながら推測を行ってください。

## 回答プロセス
1. すべての思考プロセスを<thinking>タグで囲み、複数の角度やアプローチを探ってください。
2. 解決策を明確なステップに分解し、<step>タグ内に記述してください。20ステップから始め、複雑な問題の場合は追加のステップを要求してください。
3. 各ステップの後に<count>タグを使用して、残りのステップ数を示してください。0に達したら停止します。
4. 中間結果や反省に基づいて推論を継続的に調整し、進行に応じて戦略を適応させてください。
5. <reflection>タグを使用して定期的に進捗を評価してください。推論プロセスについて批判的かつ正直に評価してください。
6. 各反省の後に、0.0から1.0の間の品質スコアを<reward>タグを使用して割り当ててください。このスコアを使用してアプローチを導いてください：
    - 0.8以上：現在のアプローチを継続
    - 0.5-0.7：軽微な調整を検討
    - 0.5未満：別のアプローチを試すことを真剣に検討
7. 不確かな場合や報酬スコアが低い場合は、バックトラックして別のアプローチを試み、<thinking>タグ内で決定を説明してください。
8. 可能な場合は複数の解決策を個別に探り、反省で各アプローチを比較してください。
9. 思考をメモ帳として使用し、すべての計算と推論を明示的に書き出してください。
10. 最終的な答え（ファイル名）を<answer>タグ内で提供し、明確で簡潔な要約を示してください。
11. 全体的な解決策について最終的な反省を行い、効果、課題、解決策について議論し、最終的な報酬スコアを割り当ててください。

## 指示
1. **txtファイルの概要確認**: 以下に与えられたファイルのタイトルと内容を確認します。各ファイルは以下の形式で提供されています：
   'ファイル名': '内容'
2. **質問の分析**: 質問の文脈やキーワードを分析します。
3. **関連性の評価**: 質問に含まれる情報がどのファイルの内容に最も関連があるかを考察します。
4. **推測**: 質問がどのファイルから出題されたと思われるかを明記します。

## Notes
- 与えられたファイルの内容の形式を踏まえて､質問に関連した文章やキーワードがどのファイルに含まれているかを逐一､注意深く確認し､ハルシネーションしないようにしてください｡

## ファイルの内容
各ファイルは１～１９までの数字＋「.txt」で記載されています。各ファイルはそれぞれ独立したある会社の統合報告書です。ファイル名と内容の対応を間違えないように注意してください｡
{textwrap.indent(str(novels), '    ')}

## 質問
{query}

回答プロセスを開始してください。
最終的な回答はファイル名のみを次のように､**<answer>ファイル名.txt</answer>タグ内**として出力してください。"""
    response = model.generate_content(prompt, generation_config=generation_config)
    return response.text.strip()


def extract_filename(text, novels):
    # まず<answer>タグ内のテキストを探す
    answer_match = re.search(r"<answer>(.*?)(</answer>|$)", text, re.DOTALL | re.IGNORECASE)
    if answer_match:
        answer_text = answer_match.group(1).strip()
    else:
        answer_text = text

    # novels.keys() 内のファイル名とマッチするか確認
    for novel_filename in novels.keys():
        if novel_filename.lower() in answer_text.lower():
            return novel_filename

    # マッチするものがない場合、テキスト全体から可能性のあるファイル名を探す
    for novel_filename in novels.keys():
        if novel_filename.lower() in text.lower():
            return novel_filename

    # それでもマッチしない場合は "不明.txt" を返す
    return "不明.txt"


# 開始位置を設定（デフォルトは1、必要に応じて変更可能）
start_index = 1

# 質問データの読み込み
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/query.csv")

# 現在の日付と時刻を取得
current_datetime = datetime.now()
date_time_folder = current_datetime.strftime("%Y%m%d%H%M")

# 出力ディレクトリのパスを作成
output_dir = f"/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/output2/{date_time_folder}"

# ディレクトリが存在しない場合は作成
os.makedirs(output_dir, exist_ok=True)

# 結果を保存するファイルのパス
output_file = os.path.join(output_dir, "query_with_predictions.csv")


# バッチ単位ずつ処理し、結果をファイルに書き込む関数
def process_and_write_batch(batch, writer, start_index, novels):
    for i, (index, query) in enumerate(batch.items(), start=start_index):
        try:
            result = extract_filename(predict_novel(query), novels)
            writer.writerow([i + 1, query, result])
            print(f"Processed question {i}: {result}")
        except Exception as e:
            print(f"Error processing query {i}: {query}")
            print(f"Error: {e}")
            writer.writerow([i + 1, query, "エラー発生"])


# バッチサイズと総バッチ数の設定
batch_size = 1
total_questions = len(df)
total_batches = (total_questions - start_index + 1 + batch_size - 1) // batch_size

# ファイルを開いて処理を開始
mode = "a" if os.path.exists(output_file) else "w"
with open(output_file, mode, newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    if mode == "w":
        writer.writerow(["index", "problem", "file"])  # ヘッダーを書き込む

    # バッチ処理の部分
    for i in range(total_batches):
        batch_start = start_index + i * batch_size - 1
        batch_end = min(batch_start + batch_size, total_questions)
        batch = df["problem"][batch_start:batch_end]

        print(f"Processing batch {i+1}/{total_batches} (questions {batch_start+1}-{batch_end})")
        process_and_write_batch(batch, writer, batch_start, novels)

        # ファイルをフラッシュして確実に書き込む
        csvfile.flush()

        # API制限を考慮して、バッチ間に少し待機時間を入れる
        #if i < total_batches - 1:
        #    print("Waiting for 60 seconds before the next batch...")
        #    time.sleep(60)  # 60秒待機

print(f"推論結果が生成され、{output_file}に保存されました。")
# Out:
# Processing batch 1/100 (questions 1-1)
# WARNING:tornado.access:400 POST /v1beta/models/gemini-1.5-pro-002:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 36544.24ms
# Error processing query 0: 高松コンストラクショングループの2025年3月期の受注高の計画は前期比何倍か、小数第三位を四捨五入し答えてください。
# Error: 400 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro-002:generateContent?%24alt=json%3Benum-encoding%3Dint: The input token count (2741460) exceeds the maximum number of tokens allowed (2000000).
# Processing batch 2/100 (questions 2-2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-ebaa6dd89d41> in <cell line: 0>()
#     160
#     161         print(f"Processing batch {i+1}/{total_batches} (questions {batch_start+1}-{batch_end})")
# --> 162         process_and_write_batch(batch, writer, batch_start, novels)
#     163
#     164         # ファイルをフラッシュして確実に書き込む
#
# ...

# %% [markdown]
# サンプルアウトプット:answerタグ内に質問に紐づく小説ファイル名がアウトプットされる

# %% [markdown]
# ## クエリの書き換え

# %%
### GPT　あまり質問文が変わらない

import csv
import os
import textwrap
import time
from datetime import datetime

import google.generativeai as genai
import pandas as pd
from dotenv import load_dotenv

"""
# .envファイルから環境変数を読み込む
load_dotenv()

# Google API Keyを環境変数から取得
google_api_key = GKEY #os.getenv("GOOGLE_API_KEY")

# Geminiモデルの初期化
genai.configure(api_key=google_api_key)

# モデルの設定
generation_config = {
    "temperature": 0.5,
    "max_output_tokens": 2048,
}

model = genai.GenerativeModel(
    model_name="gemini-1.5-pro-002",
    generation_config=generation_config,
)
"""

model = ChatOpenAI(api_key=KEY, model="gpt-4o-mini", temperature=0)


def rewrite_query(row):
    original_query = row["problem"]
    file_name = row["file"]  # 先ほど推定したファイル名

    prompt = ChatPromptTemplate.from_template('''\
    あなたは高度な自然言語処理と情報検索の専門家です。以下の統合報告書に関する質問を、文書検索システムでの検索効率と回答精度を高めるように書き換えてください。

    ## 元の質問
    {original_query}

    ## 対象のファイル
    {file_name}

    ## 指示
    1. 質問分析:
       - 質問の主要な要素（会社、場所、イベント、概念など）を特定する。
       - 質問のタイプ（事実確認、数値、比較、理由、方法など）を判断する。

    2. コンテキスト考慮:
       - 対象ファイルは企業の統合報告書です。
       - 統合報告書特有の用語や表現がある場合、それらを活用する。

    3. 質問の最適化:
       - 曖昧さを排除し、具体的で明確な表現に書き換える。
       - 検索キーワードとなる重要な単語や表現を質問の前半に配置する。
       - 会社名や固有名詞は変更せず、そのまま使用する。
       - 数値や単位が含まれる場合は保持する。

    4. 検索効率の向上:
       - 同義語や関連する表現を追加し、検索の幅を広げる。
       - 必要に応じて、質問を複数の部分に分割する。
       - 「〜は何ですか？」「〜をあげてください」などの表現は、より直接的な形に変更する。

    5. 回答形式の指定:
       - 期待される回答の形式（リスト、数値、説明など）を明確にする。

    6. 検証:
       - 書き換えた質問が元の意図を保持しているか確認する。
       - 検索システムにとって理解しやすく、かつ人間にも読みやすい表現になっているか確認する。

    7.追記：
       - ファイル名を質問文に追加し、どのファイルから回答すればよいかを明記する。ただし不明.txtの場合は明記しないでください。


    ## 出力形式
    書き換えた質問のみを出力してください。説明や理由付けは不要です。

    ## 書き換えた質問
    ''')

    #response = model.generate_content(prompt)
    #return response.text.strip()

    retriever = db.as_retriever()
    chain = {
        "file_name": RunnablePassthrough(),
        "original_query": RunnablePassthrough(),
        } | prompt | model | StrOutputParser()

    return chain.invoke({"file_name": file_name, "original_query": original_query})


# 質問データの読み込み（indexを明示的に指定）
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/output2/query_with_predictions.csv", index_col="index")

# 現在の日付と時刻を取得
current_datetime = datetime.now()
date_time_folder = current_datetime.strftime("%Y%m%d%H%M")

# 出力ディレクトリのパスを作成
output_dir = f"/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/query_plus" #/{date_time_folder}

# ディレクトリが存在しない場合は作成
os.makedirs(output_dir, exist_ok=True)

# 結果を保存するファイルのパス
output_file = os.path.join(output_dir, "query_with_rewrites2.csv")


# バッチ単位ずつ処理し、結果をファイルに書き込む関数
def process_and_write_batch(batch, writer):
    for index, row in batch.iterrows():
        try:
            result = rewrite_query(row)
            writer.writerow([index, row["problem"], result])
            print(f"Processed question {index}: Query rewritten")
        except Exception as e:
            print(f"Error processing query {index}: {row['problem']}")
            print(f"Error: {e}")
            writer.writerow([index, row["problem"], "エラー発生"])


# バッチサイズと総バッチ数の設定
batch_size = 2
total_questions = len(df)
total_batches = (total_questions + batch_size - 1) // batch_size

# ファイルを開いて処理を開始
mode = "a" if os.path.exists(output_file) else "w"
with open(output_file, mode, newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    if mode == "w":
        writer.writerow(["index", "original_query", "rewritten_query"])  # ヘッダーを書き込む

    # バッチ処理の部分
    for i in range(total_batches):
        batch_start = df.index[i * batch_size]
        batch_end = df.index[min((i + 1) * batch_size, total_questions) - 1]
        batch = df.loc[batch_start:batch_end]

        print(f"Processing batch {i+1}/{total_batches} (questions {batch_start}-{batch_end})")
        process_and_write_batch(batch, writer)

        # ファイルをフラッシュして確実に書き込む
        csvfile.flush()

        # API制限を考慮して、バッチ間に少し待機時間を入れる
        #if i < total_batches - 1:
        #    print("Waiting for 60 seconds before the next batch...")
        #    time.sleep(60)  # 60秒待機

print(f"クエリの書き換えが完了し、結果が{output_file}に保存されました。")
# Out:
# Processing batch 1/50 (questions 1-2)
# Processed question 1: Query rewritten
# Processed question 2: Query rewritten
# Processing batch 2/50 (questions 3-4)
# Processed question 3: Query rewritten
# Processed question 4: Query rewritten
# Processing batch 3/50 (questions 5-6)
# Processed question 5: Query rewritten
# Processed question 6: Query rewritten
# Processing batch 4/50 (questions 7-8)
# Processed question 7: Query rewritten
# Processed question 8: Query rewritten
# Processing batch 5/50 (questions 9-10)
# Processed question 9: Query rewritten
# Processed question 10: Query rewritten
# Processing batch 6/50 (questions 11-12)
# Processed question 11: Query rewritten
# Processed question 12: Query rewritten
# Processing batch 7/50 (questions 13-14)
# Processed question 13: Query rewritten
# Processed question 14: Query rewritten
# Processing batch 8/50 (questions 15-16)
# Processed question 15: Query rewritten
# Processed question 16: Query rewritten
# ...

# %%
### Gemini 採用！！！

import csv
import os
import textwrap
import time
from datetime import datetime

import google.generativeai as genai
import pandas as pd
from dotenv import load_dotenv

# .envファイルから環境変数を読み込む
load_dotenv()

# Google API Keyを環境変数から取得
google_api_key = GKEY #os.getenv("GOOGLE_API_KEY")

# Geminiモデルの初期化
genai.configure(api_key=google_api_key)

# モデルの設定
generation_config = {
    "temperature": 0.5,
    "max_output_tokens": 2048,
}

model = genai.GenerativeModel(
    model_name="gemini-1.5-pro-002",
    generation_config=generation_config,
)


def rewrite_query(row):
    original_query = row["problem"]
    novel_file = row["file"]  # 先ほど推定したファイル名

    prompt = f"""
    あなたは高度な自然言語処理と情報検索の専門家です。以下の統合報告書に関する質問を、文書検索システムでの検索効率と回答精度を高めるように書き換えてください。

    ## 元の質問
    {original_query}

    ## 対象の小説ファイル
    {novel_file}

    ## 指示
    1. 質問分析:
       - 質問の主要な要素（会社、場所、イベント、概念など）を特定する。
       - 質問のタイプ（事実確認、数値、比較、理由、方法など）を判断する。

    2. コンテキスト考慮:
       - 対象ファイルは企業の統合報告書です。
       - 統合報告書特有の用語や表現がある場合、それらを活用する。

    3. 質問の最適化:
       - 曖昧さを排除し、具体的で明確な表現に書き換える。
       - 検索キーワードとなる重要な単語や表現を質問の前半に配置する。
       - 会社名や固有名詞は変更せず、そのまま使用する。
       - 数値や単位が含まれる場合は保持する。

    4. 検索効率の向上:
       - 同義語や関連する表現を追加し、検索の幅を広げる。
       - 必要に応じて、質問を複数の部分に分割する。
       - 「〜は何ですか？」「〜をあげてください」などの表現は、より直接的な形に変更する。

    5. 回答形式の指定:
       - 期待される回答の形式（リスト、数値、説明など）を明確にする。

    6. 検証:
       - 書き換えた質問が元の意図を保持しているか確認する。
       - 検索システムにとって理解しやすく、かつ人間にも読みやすい表現になっているか確認する。

    7.追記：
       - ファイル名を質問文に追加し、どのファイルから回答すればよいかを明記する。ただし不明.txtは使用しないでください。

    ## 出力形式
    書き換えた質問のみを出力してください。説明や理由付けは不要です。

    ## 書き換えた質問
    """
    response = model.generate_content(prompt)
    return response.text.strip()


# 質問データの読み込み（indexを明示的に指定）
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/output2/query_with_predictions.csv", index_col="index")

# 現在の日付と時刻を取得
current_datetime = datetime.now()
date_time_folder = current_datetime.strftime("%Y%m%d%H%M")

# 出力ディレクトリのパスを作成
output_dir = f"/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/query_plus" #/{date_time_folder}

# ディレクトリが存在しない場合は作成
os.makedirs(output_dir, exist_ok=True)

# 結果を保存するファイルのパス
output_file = os.path.join(output_dir, "query_with_rewrites.csv")


# バッチ単位ずつ処理し、結果をファイルに書き込む関数
def process_and_write_batch(batch, writer):
    for index, row in batch.iterrows():
        try:
            result = rewrite_query(row)
            writer.writerow([index, row["problem"], result])
            print(f"Processed question {index}: Query rewritten")
        except Exception as e:
            print(f"Error processing query {index}: {row['problem']}")
            print(f"Error: {e}")
            writer.writerow([index, row["problem"], "エラー発生"])


# バッチサイズと総バッチ数の設定
batch_size = 2
total_questions = len(df)
total_batches = (total_questions + batch_size - 1) // batch_size

# ファイルを開いて処理を開始
mode = "a" if os.path.exists(output_file) else "w"
with open(output_file, mode, newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    if mode == "w":
        writer.writerow(["index", "original_query", "rewritten_query"])  # ヘッダーを書き込む

    # バッチ処理の部分
    for i in range(total_batches):
        batch_start = df.index[i * batch_size]
        batch_end = df.index[min((i + 1) * batch_size, total_questions) - 1]
        batch = df.loc[batch_start:batch_end]

        print(f"Processing batch {i+1}/{total_batches} (questions {batch_start}-{batch_end})")
        process_and_write_batch(batch, writer)

        # ファイルをフラッシュして確実に書き込む
        csvfile.flush()

        # API制限を考慮して、バッチ間に少し待機時間を入れる
        #if i < total_batches - 1:
        #    print("Waiting for 60 seconds before the next batch...")
        #    time.sleep(60)  # 60秒待機

print(f"クエリの書き換えが完了し、結果が{output_file}に保存されました。")
# Out:
# Processing batch 1/50 (questions 1-2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-0856731b6633> in <cell line: 0>()
#     133
#     134         print(f"Processing batch {i+1}/{total_batches} (questions {batch_start}-{batch_end})")
# --> 135         process_and_write_batch(batch, writer)
#     136
#     137         # ファイルをフラッシュして確実に書き込む
#
# <ipython-input-54-0856731b6633> in process_and_write_batch(batch, writer)
#     105     for index, row in batch.iterrows():
#     106         try:
# --> 107             result = rewrite_query(row)
#     108             writer.writerow([index, row["problem"], result])
#     109             print(f"Processed question {index}: Query rewritten")
#
# <ipython-input-54-0856731b6633> in rewrite_query(row)
#      80     ## 書き換えた質問
#      81     """
# ---> 82     response = model.generate_content(prompt)
# ...

# %% [markdown]
# 各質問に対する書き換え後の質問と小説ファイル名のデータフレーム作成

# %%
import pandas as pd

df1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/output2/query_with_predictions.csv")
df2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/query_plus/query_with_rewrites_gpt2.csv")
df_merged = pd.merge(df1, df2, how="left", on="index")
df_merged.head()

# %% [markdown]
# ### 推論コード

# %%
### その１　GPT

import csv
import os
import random
import textwrap
import time
from datetime import datetime

import google.generativeai as genai
import pandas as pd
from dotenv import load_dotenv
from google.generativeai.types import HarmBlockThreshold, HarmCategory
from tenacity import retry, stop_after_attempt, wait_exponential


model = ChatOpenAI(api_key=KEY, model="gpt-4o-mini", temperature=0)

# 質問データの読み込み
df = df_merged

# ファイルの読み込み
loader = DirectoryLoader("/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/preprocessed_documents", glob="**/*.txt", loader_cls=TextLoader)
docs = loader.load()

# 内容をディクショナリに格納
novels = {doc.metadata["source"].split("/")[-1]: doc.page_content for doc in docs}


def generate_answer2(query, rewrite_query, novel_content):
    prompt = ChatPromptTemplate.from_template('''\
## 役割と目的
あなたは企業の統合報告書の内容を分析し、その内容を元に質問に回答する専門家です。与えられた**##統合報告書の内容**のみを使用し、メタ認知を駆使して質問に答えてください。鳥の目（全体像）、魚の目（詳細）、虫の目（微細な関連性）を使い、質問に答えるための情報を詳細に探索してください。

## 回答プロセス
1. 質問分析: <thinking>タグ内で以下を行ってください
   - 元の**##質問**と**##書き換えられた質問**の比較分析
   - 回答に必要な要素の特定と優先順位付け
   - 質問に記載の回答に必ず必要な要件の明確化と整理
   - 質問の意図や前提と潜在的な複雑性の正確な理解
   - 統合報告書内の関連箇所を特定するための多角的な戦略立案
   - 複数の解釈可能性の探索と評価
</thinking>

2. 解決策の構築: 以下のステップを実行し、以下の**## 文脈理解と情報統合**や**## 回答の構築方法**､**## 厳守事項**を念頭に置き､必要に応じて追加してください。各ステップを<step>タグで囲み、<count>タグで残りのステップ数を示してください。
   <step>1. 関連箇所の網羅的特定（キーワード、類義語、文脈を活用｡出現回数のリストアップは細かく複数回､全体を確認）</step>
   <step>2. 関連情報の抽出と多層的整理（重要度、時系列、因果関係でのランク付け）</step>
   <step>3. 情報の論理的組み立て（質問に直接答える形で、矛盾点の解消）</step>
   <step>4. 根拠となる複数の引用選択（最も関連性の高い部分を優先）</step>
   <step>5. 回答の簡潔かつ包括的なまとめ（50文字以内、核心を捉えた表現）</step>

3. 反省と評価: 各ステップ後に<reflection>タグで進捗を評価し、<reward>タグで0.0から1.0の品質スコアを割り当て、以下に従ってください：
   - 0.9以上：現在のアプローチを継続
   - 0.7-0.8：軽微な調整を検討
   - 0.5-0.6：大幅な見直しを検討
   - 0.5未満：完全に新しいアプローチを採用

4. アプローチの調整:
   - 低スコアの場合、バックトラックして異なるアプローチを試み、<thinking>タグで理由を説明
   - 複数の解決策を並行して探り、最終的に最適な解を選択
   - すべての推論を明示的に記述し、中間結果や反省に基づいて継続的に調整
   - 不確実性が高い場合、複数の仮説を立てて検証

## 文脈理解と情報統合
1. 文章全体を複数回精読し、表層的な情報だけでなく、潜在的な意味や象徴性も考慮してください。
2. 時系列、空間的変化、人物関係の変遷を詳細にマッピングし、質問との関連性を多角的に分析してください。
3. 明示的情報と暗示的情報を区別し、後者の場合は推論過程を詳細に説明してください。
4. 数値や時間に関する質問では、文中の散在する情報を統合し、必要に応じて補間や外挿を行ってください。
5. 矛盾する情報がある場合、それらを整理し、最も妥当な解釈を提示してください。
6. 質問に直接関係しない情報でも、間接的に関連する可能性がある場合は、その関連性を探ってください。

## 回答の構築方法
1. 関連情報を網羅的に列挙し、それらの相互関係を多次元的に分析してください。
2. 情報の信頼性、重要度、関連性を客観的に評価し、最適な情報を選択してください。
3. 複数の解釈が可能な場合、各解釈の妥当性を評価し、最適な解釈を選択または複数の可能性を提示してください。
4. 推論や計算を行う際は、各ステップを明確に示し、使用した情報と論理の流れを詳細に説明してください。
5. 不確実な要素がある場合、その不確実性の程度と影響を明示し、どのような仮定のもとで回答を導いたかを説明してください。
6. 時間経過や年齢に関する質問では、文中の複数の情報を統合して計算を行い、その過程と仮定を明示してください。
7. 推論に基づく回答の場合、その推論の妥当性を複数の観点から検証し、可能な限り文中の情報で裏付けてください。
8. 回答の確信度を明示し、確信度が低い場合は代替の解釈や可能性も提示してください。

## 厳守事項
以下の**回答例と根拠例**を参考に、以下の各事項に従って回答してください：

1. 情報源と正確性:
   - 統合報告書の内容のみを使用し、外部知識や不適切な推測を完全に排除してください。
   - 一般常識と照らし合わせて、ありえない回答や解釈は再考してください。ただし､小説はフィクションであるため､一般常識と異なる場合もあります。
   - 質問に直接関係ない情報は慎重に除外しつつ、間接的な関連性も検討してください。
   - 数値は最大限の正確さを期し、質問が求める適切な単位を必ず付けてください。
   - 漢数字、算用数字、「〇」を含む数字表現は以下のように正確に解釈してください：
     - 漢数字→算用数字変換：十五秒=15秒、二十五秒=25秒
     - 「〇」を含む表現：二〇歳=20歳、三〇年=30年、二〇二歳=202歳、三〇三貫=303貫
   - 概数表現（例：二、三十年）は範囲として解釈し、その範囲を明示してください（例：20〜30年）。
   - 年齢や時間の経過に関する計算を行う際は、文脈から適切な情報を抽出し、論理的に推論してください。全ての仮定と計算過程を明示してください。

2. 回答の判断:
   - 参照元に答えの手がかりが全く見つからない場合のみ「分かりません」と回答してください。
   - 「分かりません」と回答する前に、あらゆる可能性を徹底的に検討してください。

3. 質問への対応:
   - 質問の内容と小説の内容を徹底的に照合し、可能な限り完全で正確な回答を目指してください。
   - 曖昧な質問に対しては、考えられる全ての解釈を示した上で、最も適切と思われる解釈に基づいて回答してください。
   - 出現回数を問う質問には、数え漏れがないよう細心の注意を払って正確に回答してください。
   - ファイルの内容を一語一句正確に理解し、文脈や含意も考慮して質問との関連性を多角的に分析してください。

4. 回答形式:
   - 提供された回答例と根拠例の形式、答え方、考え方に厳密に従ってください。
   - 回答は簡潔かつ正確であることを最優先としつつ、必要に応じて補足説明を加えてください。

## 判断基準
- 「分かりません」: ファイル内に質問や回答のための関連情報や手がかりが見つからず、合理的な推論も不可能な場合

## 情報抽出の効率化
- キーワード、類義語、関連概念のシステマティックな抽出と分析
- 文脈の多層的理解（表層的意味、含意、象徴的意味）
- 情報の重要度、信頼性、関連性に基づく多次元的な階層化と処理

## 出力形式
- 回答：<answer>[50文字以内の簡潔かつ正確な回答]</answer>
- 根拠：<evidence>[100文字以内のファイルからの直接引用と詳細な推論過程の説明]</evidence>

## 最終評価
全体的な解決策について以下の観点から最終的な反省を行ってください：
1. 回答の正確性と完全性
2. 推論過程の論理性と透明性
3. 文脈理解の深さと多角性
4. 想定外の解釈や可能性の考慮
5. 回答の簡潔さと明瞭性
最後に、これらの観点を総合的に評価し、最終的な報酬スコアを割り当ててください。

## 回答例
#### 事実確認の質問
質問: 花王の生産拠点数は何拠点ですか？
<answer>36拠点</answer>

質問: 2023年度の大成温調の連結純資産配当率（DOE）は何%でしたか？
<answer>3%</answer>

質問: 花王の取締役を除く監査役のスキルマトリックスにおいて、一番多く丸がついている方の丸の数はいくつですか？
<answer>4つ</answer>

質問: ウエルシアホールディングスが掲げる2030のありたい姿はなんですか？
<answer>地域No.1の健康ステーション</answer>

質問: 電通グループの電力使用に伴うCO2排出量ゼロを達成した撮影スタジオの名称を答えよ。
<answer>FACTORY ANZEN STUDIO</answer>


#### どちらか回答するの質問
質問: 日本化薬グループの国内グループ会社と海外グループ会社で、2023年度の中央環境安全衛生診断の実施件数はどちらが多いですか？
<answer>国内グループ会社</answer>

質問: 東洋紡の取締役の在籍期間において、0~3年と4~9年ではどちらの方が取締役の人数が多いか
<answer>0~3年</answer>

質問: 花王の製品ライフサイクル全体のCO2 排出量において2019年度と2020年度ではどちらの数値が大きいか
<answer>2019年度</answer>


#### リスト作成の質問
質問: 大成温調が積極的に資源配分を行うとしている高付加価値セグメントを全てあげてください。
<answer>改修セグメント、医療用・産業用セグメント、官公庁セグメント</answer>

質問: ダイドーグループの従業員数において、2012年から2023年までの12年間で、医薬品関連が食品を下回った年を全てあげてください。
<answer>2013年、2015年、2016年、2017年</answer>

質問: 東洋紡グループのコア技術を4つ答えてください。
<answer>高分子技術、バイオ・メディカル技術、環境技術、分析・シミュレーション技術</answer>

質問: エクシオグループの主な事業セグメントを全てあげてください。
<answer>通信キャリア、都市インフラ、システムソリューション</answer>

質問: クビアカツヤカミキリが寄生する樹木として挙げられているものの名称を全て答えよ
<answer>サクラ、ウメ</answer>


#### 計算をして答える質問
質問: 東洋紡の2023年度の売上高は2022年度と比較して何％上昇したか、少数第二位を四捨五入して答えよ
<answer>3.60%</answer>

質問: 花王の発行済株式の総数は発行可能株式総数の何％ですか？少数第二位を四捨五入して答えてください。
<answer>46.60%</answer>

質問: 大成温調の2024年3月期の売上高成長率が前期と同じであると仮定した場合、2025年3月期の売上高は何百万円になると予測できますか？十万円の位で四捨五入して答えてください。
<answer>80,228百万円</answer>


## 統合報告書の内容(Markdown形式)
{context}

## 書き換えられた質問
{rewrite_query}

## 出力
上記の各項目､特に**厳守事項**には厳密に従い、メタ認知と批判的思考､鳥の目（全体像）、魚の目（詳細）、虫の目（微細な関連性）を最大限に活用して、**回答プロセス**を開始してください。
''')

    #response = model.generate_content(prompt)
    #return response.text.strip()

    retriever = db.as_retriever()
    chain = {
        "context": retriever,
        "rewrite_query": RunnablePassthrough()
        } | prompt | model | StrOutputParser()

    return chain.invoke(rewrite_query)


def truncate_text(text, max_length=50):
    """テキストを指定された最大長さに切り詰める"""
    if len(text) > max_length:
        return text[: max_length - 3] + "..."
    return text


# バッチサイズと待機時間の設定
BATCH_SIZE = 1
WAIT_TIME = 60

# 現在の日付と時刻を取得
current_datetime = datetime.now()
date_time_folder = current_datetime.strftime("%Y%m%d%H%M")

# 出力ディレクトリのパスを作成
output_dir = f"/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/output3"  #/{date_time_folder}
# os.makedirs(output_dir, exist_ok=True)

# 出力ファイルのパスを設定
output_file = os.path.join(output_dir, "predictions.csv")


#@retry(stop=stop_after_attempt(2), wait=wait_exponential(multiplier=1, min=5, max=15))
def generate_answer_with_retry(query, rewrite_query, novel_content):
    return generate_answer2(query, rewrite_query, novel_content)


def process_batch(batch, csvfile):
    writer = csv.writer(csvfile)
    for index, row in batch.iterrows():
        query = row["problem"]
        rewrite_query = row["rewritten_query"]
        novel_file = row["file"]
        novel_content = novels.get(novel_file, "分かりません")

        try:
            generated_text = generate_answer_with_retry(query, rewrite_query, novel_content)

            answer = ""
            evidence = ""
            for line in generated_text.split("\n"):
                if "<answer>" in line:
                    answer = line[line.index("<answer>") + 8 : line.index("</answer>")].strip()
                elif "<evidence>" in line:
                    evidence = line[line.index("<evidence>") + 10 : line.index("</evidence>")].strip()

            answer = truncate_text(answer, 50)
            evidence = evidence if evidence else "なし"

            writer.writerow([index + 1, answer])
            print(f"Processed question {index}:{answer}")
        except Exception as e:
            print(f"Error processing query {index}: {query}")
            print(f"Error: {e}")
            writer.writerow([index + 1, "分かりません"])

        # ランダムな待機時間を追加して、連続的なリクエストを避ける
        # time.sleep(random.uniform(5, 10))

    csvfile.flush()


# メイン処理
with open(output_file, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    for i in range(0, len(df), BATCH_SIZE):
        batch = df.iloc[i : i + BATCH_SIZE]
        #print(f"Processing batch {i//BATCH_SIZE + 1}/{(len(df) + BATCH_SIZE - 1)//BATCH_SIZE}")

        process_batch(batch, csvfile)

        #if i + BATCH_SIZE < len(df):
        #    print(f"Waiting for {WAIT_TIME} seconds before the next batch...")
        #    time.sleep(WAIT_TIME)

print(f"回答が生成され、{output_file}に保存されました。")

# %%
### その２　Gemini

import csv
import os
import random
import textwrap
import time
from datetime import datetime

import google.generativeai as genai
import pandas as pd
from dotenv import load_dotenv
from google.generativeai.types import HarmBlockThreshold, HarmCategory
from tenacity import retry, stop_after_attempt, wait_exponential

load_dotenv()

# Google API Keyを環境変数から取得
google_api_key = GKEY #os.getenv("GOOGLE_API_KEY")

# Geminiモデルの初期化
genai.configure(api_key=google_api_key)

# モデルの設定
generation_config = {
    "temperature": 0,
    "max_output_tokens": 8192,
}

safety_config = {
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
}


model = genai.GenerativeModel(
    model_name="gemini-1.5-pro-002",
    generation_config=generation_config,
    safety_settings=safety_config,
)

# 質問データの読み込み
df = df_merged

# 内容を読み込む（前のスクリプトで作成したnovelsディクショナリを使用すると仮定）
# novels = {...}  # 内容を格納したディクショナリ

# 小説ファイルの読み込み
loader = DirectoryLoader("/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/preprocessed_documents", glob="**/*.txt", loader_cls=TextLoader)
docs = loader.load()

# 小説の内容をディクショナリに格納
novels = {doc.metadata["source"].split("/")[-1]: doc.page_content for doc in docs}


# Many-shot examples
many_shot_examples = """

### 事実確認の質問
質問: 花王の生産拠点数は何拠点ですか？
<answer>36拠点</answer>

質問: 東洋紡の取締役の在籍期間において、0~3年と4~9年ではどちらの方が取締役の人数が多いか
<answer>0~3年</answer>

質問: 2023年度の大成温調の連結純資産配当率（DOE）は何%でしたか？
<answer>3%</answer>

質問: ウエルシアホールディングスが掲げる2030のありたい姿はなんですか？
<answer>地域No.1の健康ステーション</answer>

質問: 電通グループの電力使用に伴うCO2排出量ゼロを達成した撮影スタジオの名称を答えよ。
<answer>FACTORY ANZEN STUDIO</answer>

質問: 日本化薬グループの国内グループ会社と海外グループ会社で、2023年度の中央環境安全衛生診断の実施件数はどちらが多いですか？
<answer>国内グループ会社</answer>


### リスト作成の質問
質問: 大成温調が積極的に資源配分を行うとしている高付加価値セグメントを全てあげてください。
<answer>改修セグメント、医療用・産業用セグメント、官公庁セグメント</answer>

質問: ダイドーグループの従業員数において、2012年から2023年までの12年間で、医薬品関連が食品を下回った年を全てあげてください。
<answer>2013年、2015年、2016年、2017年</answer>

質問: 東洋紡グループのコア技術を4つ答えてください。
<answer>高分子技術、バイオ・メディカル技術、環境技術、分析・シミュレーション技術</answer>

質問: エクシオグループの主な事業セグメントを全てあげてください。
<answer>通信キャリア、都市インフラ、システムソリューション</answer>

質問: クビアカツヤカミキリが寄生する樹木として挙げられているものの名称を全て答えよ
<answer>サクラ、ウメ</answer>


### 計算をして答える質問
質問: 東洋紡の2023年度の売上高は2022年度と比較して何％上昇したか、少数第二位を四捨五入して答えよ
<answer>3.60%</answer>

質問: 花王の発行済株式の総数は発行可能株式総数の何％ですか？少数第二位を四捨五入して答えてください。
<answer>46.60%</answer>

質問: 大成温調の2024年3月期の売上高成長率が前期と同じであると仮定した場合、2025年3月期の売上高は何百万円になると予測できますか？十万円の位で四捨五入して答えてください。
<answer>80,228百万円</answer>


"""


def generate_answer2(query, rewrite_query, novel_content):
    prompt = f"""
## 役割と目的
あなたは企業の統合報告書の内容を分析し、その内容を元に質問に回答する専門家です。与えられた**##統合報告書の内容**のみを使用し、メタ認知を駆使して質問に答えてください。鳥の目（全体像）、魚の目（詳細）、虫の目（微細な関連性）を使い、質問に答えるための情報を詳細に探索してください。

## 回答プロセス
1. 質問分析: <thinking>タグ内で以下を行ってください
   - 元の**##質問**と**##書き換えられた質問**の比較分析
   - 回答に必要な要素の特定と優先順位付け
   - 質問に記載の回答に必ず必要な要件の明確化と整理
   - 質問の意図や前提と潜在的な複雑性の正確な理解
   - 統合報告書内の関連箇所を特定するための多角的な戦略立案
   - 複数の解釈可能性の探索と評価
</thinking>

2. 解決策の構築: 以下のステップを実行し、以下の**## 文脈理解と情報統合**や**## 回答の構築方法**､**## 厳守事項**を念頭に置き､必要に応じて追加してください。各ステップを<step>タグで囲み、<count>タグで残りのステップ数を示してください。
   <step>1. 関連箇所の網羅的特定（キーワード、類義語、文脈を活用｡出現回数のリストアップは細かく複数回､全体を確認）</step>
   <step>2. 関連情報の抽出と多層的整理（重要度、時系列、因果関係でのランク付け）</step>
   <step>3. 情報の論理的組み立て（質問に直接答える形で、矛盾点の解消）</step>
   <step>4. 根拠となる複数の引用選択（最も関連性の高い部分を優先）</step>
   <step>5. 回答の簡潔かつ包括的なまとめ（50文字以内、核心を捉えた表現）</step>

3. 反省と評価: 各ステップ後に<reflection>タグで進捗を評価し、<reward>タグで0.0から1.0の品質スコアを割り当て、以下に従ってください：
   - 0.9以上：現在のアプローチを継続
   - 0.7-0.8：軽微な調整を検討
   - 0.5-0.6：大幅な見直しを検討
   - 0.5未満：完全に新しいアプローチを採用

4. アプローチの調整:
   - 低スコアの場合、バックトラックして異なるアプローチを試み、<thinking>タグで理由を説明
   - 複数の解決策を並行して探り、最終的に最適な解を選択
   - すべての推論を明示的に記述し、中間結果や反省に基づいて継続的に調整
   - 不確実性が高い場合、複数の仮説を立てて検証

## 文脈理解と情報統合
1. 文章全体を複数回精読し、表層的な情報だけでなく、潜在的な意味や象徴性も考慮してください。
2. 時系列、空間的変化、人物関係の変遷を詳細にマッピングし、質問との関連性を多角的に分析してください。
3. 明示的情報と暗示的情報を区別し、後者の場合は推論過程を詳細に説明してください。
4. 数値や時間に関する質問では、文中の散在する情報を統合し、必要に応じて補間や外挿を行ってください。
5. 登場人物の心理変化や動機を深く分析し、行動の背景にある理由を推測してください。
6. 作品のテーマ、時代背景、作者の意図を考慮し、個々の事象をより大きな文脈で解釈してください。
7. 矛盾する情報がある場合、それらを整理し、最も妥当な解釈を提示してください。
8. 質問に直接関係しない情報でも、間接的に関連する可能性がある場合は、その関連性を探ってください。

## 回答の構築方法
1. 関連情報を網羅的に列挙し、それらの相互関係を多次元的に分析してください。
2. 情報の信頼性、重要度、関連性を客観的に評価し、最適な情報を選択してください。
3. 複数の解釈が可能な場合、各解釈の妥当性を評価し、最適な解釈を選択または複数の可能性を提示してください。
4. 推論や計算を行う際は、各ステップを明確に示し、使用した情報と論理の流れを詳細に説明してください。
5. 不確実な要素がある場合、その不確実性の程度と影響を明示し、どのような仮定のもとで回答を導いたかを説明してください。
6. 時間経過や年齢に関する質問では、文中の複数の情報を統合して計算を行い、その過程と仮定を明示してください。
7. 推論に基づく回答の場合、その推論の妥当性を複数の観点から検証し、可能な限り文中の情報で裏付けてください。
8. 回答の確信度を明示し、確信度が低い場合は代替の解釈や可能性も提示してください。

## 厳守事項
以下の**回答例と根拠例**を参考に、以下の各事項に従って回答してください：

1. 情報源と正確性:
   - 統合報告書の内容のみを使用し、外部知識や不適切な推測を完全に排除してください。
   - 一般常識と照らし合わせて、ありえない回答や解釈は再考してください。ただし､小説はフィクションであるため､一般常識と異なる場合もあります。
   - 質問に直接関係ない情報は慎重に除外しつつ、間接的な関連性も検討してください。
   - 数値は最大限の正確さを期し、質問が求める適切な単位を必ず付けてください。
   - 漢数字、算用数字、「〇」を含む数字表現は以下のように正確に解釈してください：
     - 漢数字→算用数字変換：十五秒=15秒、二十五秒=25秒
     - 「〇」を含む表現：二〇歳=20歳、三〇年=30年、二〇二歳=202歳、三〇三貫=303貫
   - 概数表現（例：二、三十年）は範囲として解釈し、その範囲を明示してください（例：20〜30年）。
   - 年齢や時間の経過に関する計算を行う際は、文脈から適切な情報を抽出し、論理的に推論してください。全ての仮定と計算過程を明示してください。

2. 回答の判断:
   - 参照元に答えの手がかりが全く見つからない場合のみ「分かりません」と回答してください。
   - 質問自体に誤りがある場合は「質問誤り」と回答し、その理由を簡潔かつ明確に説明してください。
   - 「分かりません」「質問誤り」と回答する前に、あらゆる可能性を徹底的に検討してください。

3. 質問への対応:
   - 質問の内容と小説の内容を徹底的に照合し、可能な限り完全で正確な回答を目指してください。
   - 曖昧な質問に対しては、考えられる全ての解釈を示した上で、最も適切と思われる解釈に基づいて回答してください。
   - 出現回数を問う質問には、数え漏れがないよう細心の注意を払って正確に回答してください。
   - 小説の内容を一語一句正確に理解し、文脈や含意も考慮して質問との関連性を多角的に分析してください。

4. 回答形式:
   - 提供された回答例と根拠例の形式、答え方、考え方に厳密に従ってください。
   - 回答は簡潔かつ正確であることを最優先としつつ、必要に応じて補足説明を加えてください。

## 判断基準
- 「分かりません」: 小説内に質問や回答のための関連情報や手がかりが見つからず、合理的な推論も不可能な場合
- 「質問誤り」: 質問が小説の内容と明らかに矛盾する場合や質問の前提が間違っている場合､質問自体に論理的な誤りがある場合､質問への直接的な回答ができない場合

## 情報抽出の効率化
- キーワード、類義語、関連概念のシステマティックな抽出と分析
- 文脈の多層的理解（表層的意味、含意、象徴的意味）
- 情報の重要度、信頼性、関連性に基づく多次元的な階層化と処理

## 出力形式
- 回答：<answer>[50文字以内の簡潔かつ正確な回答]</answer>
- 根拠：<evidence>[100文字以内の小説からの直接引用と詳細な推論過程の説明]</evidence>

## 最終評価
全体的な解決策について以下の観点から最終的な反省を行ってください：
1. 回答の正確性と完全性
2. 推論過程の論理性と透明性
3. 文脈理解の深さと多角性
4. 想定外の解釈や可能性の考慮
5. 回答の簡潔さと明瞭性
最後に、これらの観点を総合的に評価し、最終的な報酬スコアを割り当ててください。

## 回答例と根拠例
{many_shot_examples}

## 統合報告書の内容
{textwrap.indent(novel_content, '    ')}

## 元の質問
{query}

## 書き換えられた質問
{rewrite_query}

## 出力
上記の各項目､特に**厳守事項**には厳密に従い、メタ認知と批判的思考､鳥の目（全体像）、魚の目（詳細）、虫の目（微細な関連性）を最大限に活用して、**回答プロセス**を開始してください。
"""
    response = model.generate_content(prompt)
    return response.text.strip()


def truncate_text(text, max_length=50):
    """テキストを指定された最大長さに切り詰める"""
    if len(text) > max_length:
        return text[: max_length - 3] + "..."
    return text


# バッチサイズと待機時間の設定
BATCH_SIZE = 1
WAIT_TIME = 60

# 現在の日付と時刻を取得
current_datetime = datetime.now()
date_time_folder = current_datetime.strftime("%Y%m%d%H%M")

# 出力ディレクトリのパスを作成
output_dir = f"/content/drive/MyDrive/Colab Notebooks/14.第３回金融データ活用チャレンジ/output3/{date_time_folder}"
# os.makedirs(output_dir, exist_ok=True)

# 出力ファイルのパスを設定
output_file = os.path.join(output_dir, "predictions.csv")


@retry(stop=stop_after_attempt(2), wait=wait_exponential(multiplier=1, min=5, max=15))
def generate_answer_with_retry(query, rewrite_query, novel_content):
    return generate_answer2(query, rewrite_query, novel_content)


def process_batch(batch, csvfile):
    writer = csv.writer(csvfile)
    for index, row in batch.iterrows():
        query = row["problem"]
        rewrite_query = row["rewritten_query"]
        novel_file = row["file"]
        novel_content = novels.get(novel_file, "小説の内容が見つかりません")

        try:
            generated_text = generate_answer_with_retry(query, rewrite_query, novel_content)

            answer = ""
            evidence = ""
            for line in generated_text.split("\n"):
                if "<answer>" in line:
                    answer = line[line.index("<answer>") + 8 : line.index("</answer>")].strip()
                elif "<evidence>" in line:
                    evidence = line[line.index("<evidence>") + 10 : line.index("</evidence>")].strip()

            answer = truncate_text(answer, 50)
            evidence = evidence if evidence else "なし"

            writer.writerow([index + 1, answer, evidence])
            print(f"Processed question {index}: Answer generated")
        except Exception as e:
            print(f"Error processing query {index}: {query}")
            print(f"Error: {e}")
            writer.writerow([index + 1, "エラー発生", "なし"])

        # ランダムな待機時間を追加して、連続的なリクエストを避ける
        time.sleep(random.uniform(5, 10))

    csvfile.flush()


# メイン処理
with open(output_file, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    for i in range(0, len(df), BATCH_SIZE):
        batch = df.iloc[i : i + BATCH_SIZE]
        print(f"Processing batch {i//BATCH_SIZE + 1}/{(len(df) + BATCH_SIZE - 1)//BATCH_SIZE}")

        process_batch(batch, csvfile)

        if i + BATCH_SIZE < len(df):
            print(f"Waiting for {WAIT_TIME} seconds before the next batch...")
            time.sleep(WAIT_TIME)

print(f"回答が生成され、{output_file}に保存されました。")

# %% [markdown]
# 出力サンプル

# %%
indices = [16]

for idx in indices:
    novel_file = df_merged.loc[idx, "file"]
    novel_content = novels.get(novel_file, "小説の内容が見つかりません")
    generated_text = generate_answer_with_retry(
        df_merged.loc[idx, "problem"],
        df_merged.loc[idx, "rewritten_query"],
        novel_content,
    )
    answer = ""
    evidence = ""
    for line in generated_text.split("\n"):
        if "<answer>" in line:
            answer = line[line.index("<answer>") + 8 : line.index("</answer>")].strip()
        elif "<evidence>" in line:
            evidence = line[line.index("<evidence>") + 10 : line.index("</evidence>")].strip()

    answer = truncate_text(answer, 50)
    evidence = evidence if evidence else "なし"
    print(generated_text)
    print(f"{idx + 1},{answer},{evidence}")
# Out:
# ## 質問
# 主人公が「最後の晩餐（ばんさん）！」と思った理由はなんですか？
#
# ## 書き換えられた質問
# 芽生.txtにおける「最後の晩餐」という言葉/表現/描写に関連して、主人公がそれを「最後」と認識した/感じた/考えた理由/原因/動機/心境を説明してください。
#
# <thinking>
# 元の質問と書き換えられた質問はほぼ同じ意味だが、書き換えられた質問の方がより詳細で、回答の範囲を明確に示している。具体的には、「最後の晩餐」という言葉が出てくる場面での主人公の心境や、なぜ「最後」と感じたのかという理由を説明することが求められている。
#
# 回答に必要な要素は、
# 1. 「最後の晩餐」という言葉が登場する具体的な文脈
# 2. 主人公の当時の状況（家族、仕事、精神状態など）
# 3. なぜ「最後」と感じたのかという理由の推測（明示的な記述がない場合は、前後の文脈から推測する）
#
# 質問の意図は、主人公の心情や行動の背後にある心理を読み解くことにある。
#
# 小説内の関連箇所を特定するための戦略は、
# 1. 「最後の晩餐」をキーワードとして検索する。
# 2. 主人公の子供の病状に関する記述を探す。
# 3. 主人公の仕事に関する記述を探す。
#
# 複数の解釈可能性としては、
# 1. 文字通りの「最後の晩餐」：子供が死んでしまうかもしれないという予感
# 2. 比喩的な「最後の晩餐」：子供の死を覚悟し、自分の生活や仕事に大きな変化が訪れることへの予感
# </thinking>
#
# <step>1. 関連箇所の網羅的特定（キーワード、類義語、文脈を活用｡出現回数のリストアップは細かく複数回､全体を確認）</step>
# <count>4</count>
# 「最後の晩餐！」は1回出現。
# 関連箇所：
# 「最早駄目かしらん、こんな気が起って来た。
# 「最後の晩餐！」
# と、不図、私は坂の途中で鷲印のミルク罐を買いながら思った。牛込の家には、種々な知人が集っていた。そこで戦地から帰って来た友達にも逢った。」
#
# <step>2. 関連情報の抽出と多層的整理（重要度、時系列、因果関係でのランク付け）</step>
# <count>3</count>
# - 末の子供（お繁）が発熱し、容態が悪化している。
# ...
